# %%
import json
import pprint
import pickle

# 3 pages of vegetarian protein recipe ingredients
# 1 pages of vegetarian recipe ingredients
# 1 pages of all 7 meat and poultry categries
# 2 pages of seafood recipe ingredients

with open('ingredients_categorized.pickle', 'rb') as f:
    ingredients = pickle.load(f)
    pprint.pprint(ingredients)
# Out:
# {'meat': {'descriptor': defaultdict(<class 'set'>,
#                                     {'(such as Guinness) or porter': {'stout'},
#                                      '(toasted) sesame oil': {'Asian'},
#                                      'Cajun seasoning': {None},
#                                      'Cheddar cheese': {'shredded',
#                                                         'shredded sharp'},
#                                      'Cheddar cheese (optional)': {'shredded'},
#                                      'Colby cheese': {'shredded'},
#                                      'Dijon mustard': {None},
#                                      "Dijon mustard (such as Hellmann's)": {None},
#                                      'Korean-style short ribs (beef chuck flanken)': {'Korean-style '
#                                                                                       'short '
#                                                                                       'flanken'},
#                                      'MEATBALLS': {None},
#                                      'Marsala wine': {None},
#                                      'Monterey Jack cheese': {'shredded'},
#                                      'Parmesan cheese': {'grated'},
#                                      'Pecorino Romano cheese': {'freshly '
#                                                                 'grated'},
#                                      'Ranch dressing': {None},
#                                      'SAUCE': {None},
#                                      'San Marzano tomatoes': {'crushed'},
#                                      'Worcestershire sauce': {None},
#                                      'Yukon Gold potatoes': {None},
#                                      'allspice': {'ground'},
#                                      'andouille sausage': {None},
#                                      'angel hair pasta': {None},
#                                      'apple': {'large'},
#                                      'apple cider': {None},
#                                      'apple cider vinegar': {None},
#                                      'apples': {'tart'},
#                                      'arrowroot powder': {None},
#                                      'bacon': {None,
#                                                'cooked',
#                                                'thick cut',
#                                                'thick sliced',
#                                                'thickly sliced'},
#                                      'bacon bits': {None},
#                                      'barbecue sauce': {None},
#                                      'barley': {None},
#                                      'basil': {'dried'},
#                                      'basil leaves': {'dried',
#                                                       'packed fresh',
#                                                       'very thinly sliced '
#                                                       'fresh'},
#                                      'basmati rice': {None},
#                                      'bay leaf': {'ground'},
#                                      'beans': {'black',
#                                                'cut green',
#                                                'great Northern',
#                                                'green',
#                                                'refried'},
#                                      'beef': {'extra lean ground',
#                                               'ground',
#                                               'lean ground'},
#                                      'beef bouillon': {None},
#                                      'beef broth': {None},
#                                      'beef chuck': {'ground'},
#                                      'beef consomme': {None},
#                                      'beef meat': {'stew'},
#                                      'beef meat (optional)': {'stew'},
#                                      'beef rib roast': {None},
#                                      'beef sirloin': {None},
#                                      'beef stock': {None},
#                                      'beef tips': {None},
#                                      'beer': {None},
#                                      'beer (such as Guinness)': {'Irish stout'},
#                                      'bell pepper': {'chopped green',
#                                                      'diced green',
#                                                      'green',
#                                                      'large green',
#                                                      'medium yellow',
#                                                      'red'},
#                                      'bell peppers': {'green', 'large green'},
#                                      'biscuit dough': {'refrigerated'},
#                                      'biscuits (such as Pillsbury Grands)': {'refrigerated '
#                                                                              'flaky-style'},
#                                      'bison': {'ground'},
#                                      'boiling water': {None},
#                                      'boneless beef chuck': {None},
#                                      'boneless lamb shoulder': {None},
#                                      'boneless pork loin roast': {None},
#                                      'boneless pork ribs': {None},
#                                      'boneless skinless chicken breasts': {None},
#                                      'boneless venison roast': {None},
#                                      'bow tie pasta': {None},
#                                      'bread': {'multigrain', None},
#                                      'bread crumbs': {None,
#                                                       'Italian seasoned',
#                                                       'Italian-seasoned',
#                                                       'Italian-style seasoned',
#                                                       'dried',
#                                                       'dry',
#                                                       'fresh',
#                                                       'seasoned'},
#                                      'bread rounds': {None},
#                                      'broccoli florets': {None},
#                                      'bucatini pasta': {None},
#                                      'buffalo': {'ground'},
#                                      'buffalo meat': {'ground'},
#                                      'bulk sausage': {'Italian',
#                                                       'mild Italian'},
#                                      'buns': {None},
#                                      'butter': {'unsalted', None, 'melted'},
#                                      'cabbage': {None},
#                                      'cannellini beans': {None},
#                                      'canola oil': {None},
#                                      'cardamom': {'ground'},
#                                      'cardamom pods': {'black'},
#                                      'carrot': {None, 'small'},
#                                      'carrots': {None,
#                                                  'diced',
#                                                  'frozen cut',
#                                                  'large',
#                                                  'medium',
#                                                  'sliced',
#                                                  'thinly sliced'},
#                                      'cayenne pepper': {None, 'ground'},
#                                      'celery': {None,
#                                                 'chopped',
#                                                 'diced',
#                                                 'sliced'},
#                                      'celery salt': {None},
#                                      'celery seed': {None},
#                                      'cheese': {'Swiss',
#                                                 'crumbled feta',
#                                                 'feta',
#                                                 'ricotta'},
#                                      'cheese (such as Dubliner)': {'Irish'},
#                                      'chicken': {'cooked', 'whole'},
#                                      'chicken bouillon granules': {None},
#                                      'chicken breast meat': {'cubed cooked'},
#                                      'chicken broth': {None,
#                                                        'condensed',
#                                                        'low-sodium',
#                                                        'lower-sodium'},
#                                      'chicken stock': {None},
#                                      'chicken thighs': {None},
#                                      'chickens': {'whole'},
#                                      'chiles': {'diced green'},
#                                      'chiles (optional)': {'diced green'},
#                                      'chili beans': {None},
#                                      'chili beans in sauce': {'spicy'},
#                                      'chili peppers': {'diced green'},
#                                      'chili powder': {None},
#                                      'chili seasoning mix': {None},
#                                      'chilies': {'minced Thai'},
#                                      'chipotle pepper': {'dried'},
#                                      'chopped fresh rosemary': {'chopped fresh '
#                                                                 'rosemary'},
#                                      'chopped giardiniera (pickled Italian vegetables)': {'chopped '
#                                                                                           'Italian'},
#                                      'chops': {None},
#                                      'chunk chicken': {None},
#                                      'chutney': {'finely chopped'},
#                                      'cider vinegar': {None},
#                                      'cilantro': {'chopped',
#                                                   'chopped fresh',
#                                                   'dried',
#                                                   'fresh'},
#                                      'cilantro (optional)': {'chopped'},
#                                      'cilantro chutney': {'spicy'},
#                                      'cilantro leaves': {'chopped fresh'},
#                                      'cinnamon': {'ground'},
#                                      'clove garlic': {None},
#                                      'cloves': {'whole', 'ground'},
#                                      'cloves garlic': {'large'},
#                                      'cocoa powder': {'unsweetened'},
#                                      'coconut milk': {None},
#                                      'coconut oil': {None},
#                                      'cooked': {'cooked'},
#                                      'cooking oats': {'quick'},
#                                      'cooking oil': {None},
#                                      'cooking sherry': {None},
#                                      'cooking spray': {None},
#                                      'cooking wine': {'red'},
#                                      'coriander': {'ground'},
#                                      'corn': {'cream-style', 'frozen'},
#                                      'corn chips as Fritos': {'such'},
#                                      'cornstarch': {None},
#                                      'cornstarch (optional)': {None},
#                                      'cracker crumbs': {'finely crushed '
#                                                         'saltine'},
#                                      'crackers': {'chicken-flavored',
#                                                   'crushed buttery round'},
#                                      'cream': {'half-and-half',
#                                                'heavy',
#                                                'sour'},
#                                      'cream (optional)': {'sour'},
#                                      'cream cheese': {None},
#                                      'cream cheese with chives': {None},
#                                      'cream of chicken soup': {'condensed'},
#                                      'cream of mushroom soup': {'condensed'},
#                                      'cream of potato soup': {'condensed'},
#                                      'cubed beef stew meat': {'cubed stew'},
#                                      'cumin': {None, 'ground'},
#                                      'currant': {'jelly'},
#                                      'curry powder': {None},
#                                      'deer chops (venison)': {None},
#                                      'diced tomatoes with green chile peppers': {'diced '
#                                                                                  'green '
#                                                                                  'chile'},
#                                      'diced tomatoes with green chiles': {'diced '
#                                                                           'green'},
#                                      'diced tomatoes with green chilies': {'diced '
#                                                                            'green'},
#                                      'dried rosemary': {'dried rosemary'},
#                                      'drops pepper sauce': {'hot'},
#                                      'duck': {'whole', 'frozen'},
#                                      'egg': {None},
#                                      'egg noodles': {'uncooked'},
#                                      'eggs': {'hard-cooked', None, 'large'},
#                                      'elbow macaroni': {None},
#                                      'elk loin (backstrap)': {None},
#                                      'elk meat': {'ground'},
#                                      'fennel seeds': {None},
#                                      'fish sauce': {None},
#                                      'florets': {'cauliflower'},
#                                      'flour': {'all-purpose'},
#                                      'flour for coating': {'all-purpose'},
#                                      'forest mushroom blend': {'dried'},
#                                      'fresh rosemary': {'fresh rosemary'},
#                                      'frozen hash brown potatoes': {'frozen '
#                                                                     'brown'},
#                                      'fusilli (spiral) pasta': {None},
#                                      'garam masala': {None},
#                                      'garbanzo beans': {None},
#                                      'garlic': {None,
#                                                 'chopped',
#                                                 'crushed',
#                                                 'minced'},
#                                      'garlic cloves': {'crushed', None},
#                                      'garlic paste': {None},
#                                      'garlic powder': {None},
#                                      'garlic powder (such as McCormick California Style)': {None},
#                                      'garlic salt': {None},
#                                      'ginger': {'freshly grated', 'ground'},
#                                      'ginger paste': {None},
#                                      'ginger root': {'chopped fresh',
#                                                      'fresh',
#                                                      'grated fresh'},
#                                      'ground dried rosemary': {'ground dried '
#                                                                'rosemary'},
#                                      'ground nutmeg': {'ground nutmeg'},
#                                      'ground veal': {'ground veal'},
#                                      'ground white or black pepper': {'ground '
#                                                                       'white '
#                                                                       'black'},
#                                      'guanciale (cured pork cheek)': {None},
#                                      'ham': {'diced cooked', None},
#                                      'hamburger buns': {'large'},
#                                      'hoisin sauce': {None},
#                                      'homemade chicken broth or low-sodium ned broth': {'homemade '
#                                                                                         'low-sodium '
#                                                                                         'ned'},
#                                      'honey': {None},
#                                      'jalapeno pepper slices': {None},
#                                      'juice': {'fresh unsweetened pomegranate'},
#                                      'kernel corn': {'frozen whole', 'whole'},
#                                      'ketchup': {None},
#                                      'kidney beans': {None, 'light red'},
#                                      'lamb': {'cubed cooked',
#                                               'ground',
#                                               'lean ground'},
#                                      'lamb chops': {None},
#                                      'lamb meat': {'stew', None, 'cubed'},
#                                      'leaf': {None},
#                                      'leaves': {None},
#                                      'leg of lamb': {'whole'},
#                                      'lemon': {None},
#                                      'lemon juice': {None},
#                                      'lemon wedges (optional)': {'fresh'},
#                                      'lemon zest': {None},
#                                      'lemons': {None},
#                                      'lentils': {'green'},
#                                      'lime juice': {'fresh'},
#                                      'loin chops )': {'(1-inch thick'},
#                                      'luncheon meat (such as SPAM)': {'fully '
#                                                                       'cooked'},
#                                      'margarine': {None},
#                                      'marjoram': {'dried'},
#                                      'mashed': {'mashed'},
#                                      'mayonnaise': {None},
#                                      'milk': {'skim', None, 'warm'},
#                                      'minced fresh rosemary': {'minced fresh '
#                                                                'rosemary'},
#                                      'mint leaves': {'chopped fresh'},
#                                      'mirin (Japanese wine)': {'sweet'},
#                                      'molasses': {None},
#                                      'mozzarella cheese': {None},
#                                      'mushroom soup': {'condensed golden'},
#                                      'mushrooms': {'dried shiitake',
#                                                    'fresh',
#                                                    'sliced',
#                                                    'sliced fresh'},
#                                      'mustard': {'prepared',
#                                                  'prepared Dijon-style',
#                                                  'prepared yellow'},
#                                      'mustard powder': {None, 'dry'},
#                                      'noodles': {None},
#                                      'oil': {'vegetable'},
#                                      'oil for frying': {'vegetable'},
#                                      'olive oil': {None, 'extra-virgin'},
#                                      'olives': {'Spanish-style',
#                                                 'black',
#                                                 'chopped black',
#                                                 'chopped green'},
#                                      'onion': {None,
#                                                'chopped',
#                                                'chopped yellow',
#                                                'diced',
#                                                'extra large',
#                                                'extra-large Spanish',
#                                                'finely chopped',
#                                                'finely minced',
#                                                'grated',
#                                                'large',
#                                                'large yellow',
#                                                'medium',
#                                                'minced',
#                                                'red',
#                                                'sliced red',
#                                                'small',
#                                                'small red',
#                                                'thinly sliced'},
#                                      'onion (optional)': {'medium red'},
#                                      'onion powder': {None},
#                                      'onion salt': {None},
#                                      'onion soup': {'condensed French'},
#                                      'onion soup mix': {'dry'},
#                                      'onions': {None,
#                                                 'chopped green',
#                                                 'green',
#                                                 'large',
#                                                 'large yellow',
#                                                 'medium',
#                                                 'small'},
#                                      'or bottle beer': {None},
#                                      'or bottle root beer': {None},
#                                      'orange': {'orange'},
#                                      'oregano': {'chopped fresh',
#                                                  'crumbled dried',
#                                                  'dried'},
#                                      'oyster sauce': {None},
#                                      'packet base (such as Swanson Vegetable Flavor Boost) (optional)': {'concentrated '
#                                                                                                          'vegetable'},
#                                      'pan drippings from rib': {'prime'},
#                                      'paprika': {None, 'smoked'},
#                                      'parsley': {'chopped fresh',
#                                                  'chopped fresh flat-leaf',
#                                                  'dried',
#                                                  'fresh',
#                                                  'minced flat-leaf',
#                                                  'minced fresh'},
#                                      'parsnip': {'parsnip'},
#                                      'partridge breast halves': {None},
#                                      'pears': {None},
#                                      'peas': {None, 'frozen green', 'frozen'},
#                                      'peas and carrots': {'frozen'},
#                                      'pecans (optional)': {None},
#                                      'peeled': {'peeled'},
#                                      'peeled and diced potatoes': {'peeled '
#                                                                    'diced'},
#                                      'pepper': {None,
#                                                 'black',
#                                                 'chile',
#                                                 'crushed red',
#                                                 'freshly ground black',
#                                                 'ground black',
#                                                 'ground red',
#                                                 'ground white',
#                                                 'white'},
#                                      'pepper flakes': {'crushed red', 'red'},
#                                      'pepper sauce': {'hot'},
#                                      'pepper sauce (e.g. Tabasco)': {'hot'},
#                                      "pepper sauce (such as Frank's )": {'Red '
#                                                                          'Hot'},
#                                      "pepper sauce (such as Frank's RedHot)": {'hot'},
#                                      'pepper sauce (such as Tabasco)': {'hot'},
#                                      'peppercorns': {'black'},
#                                      'peppers': {'chopped green chile',
#                                                  'green chile'},
#                                      'pheasant': {'pheasant'},
#                                      'phyllo dough': {None},
#                                      'pie crusts': {'unbaked'},
#                                      'pinto beans': {None},
#                                      'pita breads': {None},
#                                      'pizza crust dough': {None},
#                                      'plum jam': {None},
#                                      'plum tomatoes': {'Italian-style'},
#                                      'plum wine': {'Asian'},
#                                      'pork': {'ground'},
#                                      'pork belly': {'whole'},
#                                      'pork chops': {'thick'},
#                                      'pork ribs': {None},
#                                      'pork sausage': {'spicy ground'},
#                                      'pork shoulder roast': {None},
#                                      'pork shoulder roast (butt roast)': {None},
#                                      'port wine': {None},
#                                      'portobello mushroom cap': {None},
#                                      'pot roast': {None},
#                                      'potatoes': {None,
#                                                   'large',
#                                                   'prepared mashed',
#                                                   'red',
#                                                   'small'},
#                                      'powder': {'Chinese five-spice'},
#                                      'provolone cheese': {None},
#                                      'pureed chipotle peppers in adobo sauce': {None},
#                                      'rabbit meat': {None},
#                                      'rack baby pork ribs': {'back'},
#                                      'rack of lamb': {None},
#                                      'ranch dressing': {None},
#                                      'ribs': {None},
#                                      'rice': {'cooked white',
#                                               'hot cooked',
#                                               'uncooked',
#                                               'uncooked white'},
#                                      'roast': {None},
#                                      'rolls': {None, 'French'},
#                                      'rump roast': {None},
#                                      'rutabaga': {'small'},
#                                      'saffron': {None},
#                                      'sage': {'dried'},
#                                      'salad dressing': {'Italian'},
#                                      'salad dressing mix': {'dry '
#                                                             'Italian-style'},
#                                      'salsa': {None},
#                                      'salt': {None, 'kosher', 'seasoned'},
#                                      'salt and pepper': {None,
#                                                          'black',
#                                                          'ground black'},
#                                      'sauce': {'Asian chili-garlic',
#                                                'barbeque',
#                                                'enchilada',
#                                                'hot'},
#                                      'sauce (such as Louisiana)': {'hot'},
#                                      'sausage': {'Italian', 'sweet Italian'},
#                                      'savory': {'dried'},
#                                      'sazon seasoning (such as Badia )': {'Tropical'},
#                                      'sea salt': {None, 'coarse'},
#                                      'seasoning': {'Greek', 'Italian'},
#                                      'seasoning salt': {None},
#                                      'seeds': {'pomegranate'},
#                                      'shallots': {None,
#                                                   'finely chopped',
#                                                   'minced',
#                                                   'sliced'},
#                                      'shanks': {None},
#                                      'sherry': {None, 'dry'},
#                                      'shoulder roast': {None},
#                                      'shredded': {'shredded'},
#                                      'shrimp without tails': {'frozen cooked'},
#                                      'size flour tortillas': {None},
#                                      'skewers': {None},
#                                      'skinless': {None, 'whole', 'frozen'},
#                                      'small butternut squash': {'small squash'},
#                                      'smoke flavoring': {'liquid'},
#                                      'smokie sausages': {'little'},
#                                      'soy sauce': {'reduced-sodium', None},
#                                      'spaghetti sauce': {None},
#                                      'spinach': {'fresh', None},
#                                      'sprig': {'fresh rosemary'},
#                                      'sriracha sauce': {None},
#                                      'steak sauce': {None},
#                                      'steak seasoning': {None},
#                                      'steak seasoning rub': {None},
#                                      'stewed': {'stewed'},
#                                      'sticks': {None},
#                                      'sugar': {None,
#                                                'brown',
#                                                'dark brown',
#                                                'light brown',
#                                                'packed brown',
#                                                'white'},
#                                      'sugar (optional)': {'white'},
#                                      'taco sauce': {None},
#                                      'taco seasoning': {None},
#                                      'taco seasoning mix': {None},
#                                      'tarragon': {'dried'},
#                                      'tenderloin': {None},
#                                      'thyme': {'chopped fresh',
#                                                'dried',
#                                                'fresh',
#                                                'ground',
#                                                'ground dried'},
#                                      'tomato juice': {None},
#                                      'tomato paste': {None, 'sun-dried'},
#                                      'tomato sauce': {'canned', None},
#                                      'tomato soup': {None, 'condensed'},
#                                      'tomatoes': {None,
#                                                   'Italian-style stewed',
#                                                   'canned diced',
#                                                   'crushed',
#                                                   'diced',
#                                                   'large',
#                                                   'petite diced',
#                                                   'sliced oil-packed sun-dried',
#                                                   'stewed',
#                                                   'whole peeled'},
#                                      'tomatoes with juice': {'diced',
#                                                              'stewed',
#                                                              'whole peeled'},
#                                      'toothpicks': {None},
#                                      'tortellini pasta': {'fresh'},
#                                      'tortilla chips (optional)': {'crushed'},
#                                      'tortillas': {None},
#                                      'turmeric': {'ground'},
#                                      'turmeric powder': {None},
#                                      'venison': {None, 'ground'},
#                                      'venison backstrap': {None},
#                                      'venison meat': {'stew'},
#                                      'venison steaks': {None},
#                                      'venison tenderloin': {None},
#                                      'vermicelli pasta': {None},
#                                      'vinegar': {'aged balsamic',
#                                                  'balsamic',
#                                                  'distilled white',
#                                                  'white'},
#                                      'water': {'hot', None, 'cold'},
#                                      'water (optional)': {None},
#                                      'water as': {'needed'},
#                                      'wedges': {None},
#                                      'whipping cream': {'heavy'},
#                                      'wine': {'dry red',
#                                               'dry white',
#                                               'red',
#                                               'white'},
#                                      'wine vinegar': {None, 'red', 'white'},
#                                      'yogurt': {'plain'},
#                                      'yolk': {None},
#                                      'your barbecue sauce': {'favorite'},
#                                      'ziti pasta': {'dry'},
#                                      'zucchini': {'sliced', None, 'small'}}),
#           'ingredients': {'(such as Guinness) or porter': 1,
#                           '(toasted) sesame oil': 1,
#                           'Cajun seasoning': 1,
#                           'Cheddar cheese': 11,
#                           'Cheddar cheese (optional)': 1,
#                           'Colby cheese': 1,
#                           'Dijon mustard': 1,
#                           "Dijon mustard (such as Hellmann's)": 1,
#                           'Korean-style short ribs (beef chuck flanken)': 1,
#                           'MEATBALLS': 1,
#                           'Marsala wine': 2,
#                           'Monterey Jack cheese': 1,
#                           'Parmesan cheese': 10,
#                           'Pecorino Romano cheese': 1,
#                           'Ranch dressing': 1,
#                           'SAUCE': 1,
#                           'San Marzano tomatoes': 1,
#                           'Worcestershire sauce': 23,
#                           'Yukon Gold potatoes': 1,
#                           'allspice': 3,
#                           'andouille sausage': 1,
#                           'angel hair pasta': 1,
#                           'apple': 1,
#                           'apple cider': 1,
#                           'apple cider vinegar': 2,
#                           'apples': 1,
#                           'arrowroot powder': 1,
#                           'bacon': 12,
#                           'bacon bits': 2,
#                           'barbecue sauce': 1,
#                           'barley': 1,
#                           'basil': 10,
#                           'basil leaves': 4,
#                           'basmati rice': 1,
#                           'bay leaf': 1,
#                           'beans': 6,
#                           'beef': 21,
#                           'beef bouillon': 6,
#                           'beef broth': 13,
#                           'beef chuck': 2,
#                           'beef consomme': 1,
#                           'beef meat': 1,
#                           'beef meat (optional)': 1,
#                           'beef rib roast': 1,
#                           'beef sirloin': 1,
#                           'beef stock': 2,
#                           'beef tips': 1,
#                           'beer': 2,
#                           'beer (such as Guinness)': 1,
#                           'bell pepper': 11,
#                           'bell peppers': 2,
#                           'biscuit dough': 1,
#                           'biscuits (such as Pillsbury Grands)': 1,
#                           'bison': 1,
#                           'boiling water': 2,
#                           'boneless beef chuck': 1,
#                           'boneless lamb shoulder': 2,
#                           'boneless pork loin roast': 1,
#                           'boneless pork ribs': 1,
#                           'boneless skinless chicken breasts': 1,
#                           'boneless venison roast': 3,
#                           'bow tie pasta': 1,
#                           'bread': 2,
#                           'bread crumbs': 11,
#                           'bread rounds': 1,
#                           'broccoli florets': 1,
#                           'bucatini pasta': 1,
#                           'buffalo': 1,
#                           'buffalo meat': 1,
#                           'bulk sausage': 3,
#                           'buns': 4,
#                           'butter': 24,
#                           'cabbage': 1,
#                           'cannellini beans': 1,
#                           'canola oil': 2,
#                           'cardamom': 1,
#                           'cardamom pods': 1,
#                           'carrot': 2,
#                           'carrots': 15,
#                           'cayenne pepper': 16,
#                           'celery': 16,
#                           'celery salt': 2,
#                           'celery seed': 1,
#                           'cheese': 7,
#                           'cheese (such as Dubliner)': 1,
#                           'chicken': 3,
#                           'chicken bouillon granules': 4,
#                           'chicken breast meat': 1,
#                           'chicken broth': 17,
#                           'chicken stock': 2,
#                           'chicken thighs': 1,
#                           'chickens': 2,
#                           'chiles': 1,
#                           'chiles (optional)': 1,
#                           'chili beans': 4,
#                           'chili beans in sauce': 2,
#                           'chili peppers': 1,
#                           'chili powder': 15,
#                           'chili seasoning mix': 1,
#                           'chilies': 1,
#                           'chipotle pepper': 1,
#                           'chopped fresh rosemary': 3,
#                           'chopped giardiniera (pickled Italian vegetables)': 1,
#                           'chops': 8,
#                           'chunk chicken': 1,
#                           'chutney': 1,
#                           'cider vinegar': 2,
#                           'cilantro': 9,
#                           'cilantro (optional)': 1,
#                           'cilantro chutney': 1,
#                           'cilantro leaves': 1,
#                           'cinnamon': 8,
#                           'clove garlic': 9,
#                           'cloves': 3,
#                           'cloves garlic': 1,
#                           'cocoa powder': 1,
#                           'coconut milk': 1,
#                           'coconut oil': 1,
#                           'cooked': 1,
#                           'cooking oats': 1,
#                           'cooking oil': 1,
#                           'cooking sherry': 2,
#                           'cooking spray': 2,
#                           'cooking wine': 1,
#                           'coriander': 6,
#                           'corn': 2,
#                           'corn chips as Fritos': 2,
#                           'cornstarch': 4,
#                           'cornstarch (optional)': 1,
#                           'cracker crumbs': 1,
#                           'crackers': 2,
#                           'cream': 10,
#                           'cream (optional)': 2,
#                           'cream cheese': 5,
#                           'cream cheese with chives': 1,
#                           'cream of chicken soup': 2,
#                           'cream of mushroom soup': 6,
#                           'cream of potato soup': 1,
#                           'cubed beef stew meat': 2,
#                           'cumin': 22,
#                           'currant': 1,
#                           'curry powder': 1,
#                           'deer chops (venison)': 1,
#                           'diced tomatoes with green chile peppers': 1,
#                           'diced tomatoes with green chiles': 1,
#                           'diced tomatoes with green chilies': 1,
#                           'dried rosemary': 6,
#                           'drops pepper sauce': 1,
#                           'duck': 3,
#                           'egg': 10,
#                           'egg noodles': 1,
#                           'eggs': 9,
#                           'elbow macaroni': 1,
#                           'elk loin (backstrap)': 1,
#                           'elk meat': 1,
#                           'fennel seeds': 2,
#                           'fish sauce': 1,
#                           'florets': 1,
#                           'flour': 19,
#                           'flour for coating': 1,
#                           'forest mushroom blend': 1,
#                           'fresh rosemary': 1,
#                           'frozen hash brown potatoes': 1,
#                           'fusilli (spiral) pasta': 1,
#                           'garam masala': 2,
#                           'garbanzo beans': 1,
#                           'garlic': 55,
#                           'garlic cloves': 2,
#                           'garlic paste': 1,
#                           'garlic powder': 23,
#                           'garlic powder (such as McCormick California Style)': 1,
#                           'garlic salt': 7,
#                           'ginger': 9,
#                           'ginger paste': 1,
#                           'ginger root': 3,
#                           'ground dried rosemary': 2,
#                           'ground nutmeg': 3,
#                           'ground veal': 1,
#                           'ground white or black pepper': 1,
#                           'guanciale (cured pork cheek)': 1,
#                           'ham': 3,
#                           'hamburger buns': 1,
#                           'hoisin sauce': 1,
#                           'homemade chicken broth or low-sodium ned broth': 1,
#                           'honey': 6,
#                           'jalapeno pepper slices': 1,
#                           'juice': 1,
#                           'kernel corn': 2,
#                           'ketchup': 14,
#                           'kidney beans': 4,
#                           'lamb': 11,
#                           'lamb chops': 2,
#                           'lamb meat': 3,
#                           'leaf': 8,
#                           'leaves': 5,
#                           'leg of lamb': 1,
#                           'lemon': 4,
#                           'lemon juice': 7,
#                           'lemon wedges (optional)': 1,
#                           'lemon zest': 2,
#                           'lemons': 1,
#                           'lentils': 1,
#                           'lime juice': 1,
#                           'loin chops )': 1,
#                           'luncheon meat (such as SPAM)': 1,
#                           'margarine': 3,
#                           'marjoram': 3,
#                           'mashed': 1,
#                           'mayonnaise': 3,
#                           'milk': 14,
#                           'minced fresh rosemary': 2,
#                           'mint leaves': 3,
#                           'mirin (Japanese wine)': 1,
#                           'molasses': 1,
#                           'mozzarella cheese': 3,
#                           'mushroom soup': 2,
#                           'mushrooms': 4,
#                           'mustard': 6,
#                           'mustard powder': 3,
#                           'noodles': 2,
#                           'oil': 17,
#                           'oil for frying': 1,
#                           'olive oil': 33,
#                           'olives': 4,
#                           'onion': 72,
#                           'onion (optional)': 1,
#                           'onion powder': 6,
#                           'onion salt': 1,
#                           'onion soup': 2,
#                           'onion soup mix': 5,
#                           'onions': 13,
#                           'or bottle beer': 2,
#                           'or bottle root beer': 1,
#                           'orange': 1,
#                           'oregano': 27,
#                           'oyster sauce': 1,
#                           'packet base (such as Swanson Vegetable Flavor Boost) (optional)': 1,
#                           'pan drippings from rib': 1,
#                           'paprika': 14,
#                           'parsley': 21,
#                           'parsnip': 1,
#                           'partridge breast halves': 1,
#                           'pears': 1,
#                           'peas': 5,
#                           'peas and carrots': 1,
#                           'pecans (optional)': 1,
#                           'peeled': 1,
#                           'peeled and diced potatoes': 2,
#                           'pepper': 67,
#                           'pepper flakes': 7,
#                           'pepper sauce': 2,
#                           'pepper sauce (e.g. Tabasco)': 2,
#                           "pepper sauce (such as Frank's )": 1,
#                           "pepper sauce (such as Frank's RedHot)": 1,
#                           'pepper sauce (such as Tabasco)': 2,
#                           'peppercorns': 1,
#                           'peppers': 5,
#                           'pheasant': 1,
#                           'phyllo dough': 1,
#                           'pie crusts': 1,
#                           'pinto beans': 2,
#                           'pita breads': 1,
#                           'pizza crust dough': 1,
#                           'plum jam': 1,
#                           'plum tomatoes': 1,
#                           'plum wine': 1,
#                           'pork': 1,
#                           'pork belly': 1,
#                           'pork chops': 1,
#                           'pork ribs': 1,
# ...
#                                                                '1-inch strips',
#                                                                'halved and '
#                                                                'sliced',
#                                                                'halved '
#                                                                'lengthwise',
#                                                                'minced',
#                                                                'sliced',
#                                                                'thinly sliced '
#                                                                'diagonally',
#                                                                'whites cut '
#                                                                'thinly across '
#                                                                'and greens '
#                                                                'sliced into '
#                                                                'thin lengths, '
#                                                                'divided'},
#                                                     'oregano': {None,
#                                                                 'divided'},
#                                                     'oyster sauce': {None},
#                                                     'paprika': {None},
#                                                     'parsley': {None},
#                                                     'pasta': {None},
#                                                     'pasta shells': {None},
#                                                     'paste': {None},
#                                                     'peanut butter': {None},
#                                                     'peanut oil': {None},
#                                                     'peanut sauce': {None},
#                                                     'peanuts': {None},
#                                                     'peas': {None, 'thawed'},
#                                                     'pecans': {None},
#                                                     'pepper': {None,
#                                                                'chopped',
#                                                                'seeded and '
#                                                                'minced'},
#                                                     'pepper (optional)': {None},
#                                                     'pepper flakes': {None},
#                                                     'pepper paste': {None},
#                                                     'peppers': {None,
#                                                                 'seeded and '
#                                                                 'minced'},
#                                                     'pickle relish': {None},
#                                                     'pie crust': {None},
#                                                     'piece ginger root': {'peeled '
#                                                                           'and '
#                                                                           'minced',
#                                                                           'thinly '
#                                                                           'sliced'},
#                                                     'polenta': {None},
#                                                     'potatoes': {None,
#                                                                  'cubed',
#                                                                  'peeled and '
#                                                                  'cut into '
#                                                                  '1-inch cubes',
#                                                                  'quartered'},
#                                                     'poultry seasoning': {None},
#                                                     'protein': {None},
#                                                     'protein (TVP)': {None},
#                                                     'raisins': {None},
#                                                     'rice': {None},
#                                                     'rice vermicelli': {None},
#                                                     'rice vinegar': {None},
#                                                     'rice wine vinegar': {None},
#                                                     'rolls': {'split and '
#                                                               'toasted'},
#                                                     'rotini pasta': {None},
#                                                     'rye bread': {None},
#                                                     'sage': {None},
#                                                     'salsa': {None, 'divided'},
#                                                     'salt': {None},
#                                                     'salt and pepper': {None},
#                                                     'sauce': {None},
#                                                     'sauerkraut': {None},
#                                                     'sausage links (such as Morningstar Farms)': {None},
#                                                     'savory': {None},
#                                                     'seashell pasta': {None},
#                                                     'seasoning': {None},
#                                                     'seitan': {None},
#                                                     'semisweet chocolate chips': {None},
#                                                     'sesame oil': {None,
#                                                                    'divided'},
#                                                     'sesame seeds': {None},
#                                                     'shallots': {'thinly '
#                                                                  'sliced'},
#                                                     'shredded': {'reduced-fat '
#                                                                  'mild '
#                                                                  'Cheddar-mozzarella '
#                                                                  'cheese '
#                                                                  'blend'},
#                                                     'small head cauliflower': {'cut '
#                                                                                'into '
#                                                                                'florets'},
#                                                     'smoke flavoring': {None},
#                                                     'snow peas': {'trimmed'},
#                                                     'soy cheese': {None},
#                                                     'soy margarine': {None},
#                                                     'soy milk': {None},
#                                                     'soy sauce': {None,
#                                                                   'divided'},
#                                                     'spaghetti sauce': {None},
#                                                     'spinach': {'stems removed',
#                                                                 'thawed and '
#                                                                 'drained',
#                                                                 'washed and '
#                                                                 'chopped'},
#                                                     'spinach leaves': {None},
#                                                     'spray': {None},
#                                                     'sprig dill weed': {'chopped'},
#                                                     'sriracha chili garlic sauce': {None},
#                                                     'sugar': {None},
#                                                     'sweetened': {'plain soy '
#                                                                   'milk'},
#                                                     'taco seasoning mix': {None},
#                                                     'taco shells': {'heated'},
#                                                     'tamari': {None},
#                                                     'tempeh': {None,
#                                                                'broken into '
#                                                                'bite-sized '
#                                                                'pieces',
#                                                                'coarsely '
#                                                                'grated',
#                                                                'crumbled'},
#                                                     'thousand island salad dressing': {None},
#                                                     'thyme': {None},
#                                                     'toasted sesame oil': {None},
#                                                     'tofu': {None,
#                                                              'crumbled',
#                                                              'cubed',
#                                                              'cut into 1-inch '
#                                                              'cubes',
#                                                              'cut into '
#                                                              '1/4-inch cubes',
#                                                              'cut into 3/4 '
#                                                              'inch cubes',
#                                                              'cut into '
#                                                              'bite-size pieces',
#                                                              'cut into '
#                                                              'bite-sized cubes',
#                                                              'diced',
#                                                              'drained',
#                                                              'drained and '
#                                                              'cubed',
#                                                              'drained and cut '
#                                                              'into cubes',
#                                                              'drained and cut '
#                                                              'into strips',
#                                                              'drained and '
#                                                              'diced',
#                                                              'drained and '
#                                                              'pressed',
#                                                              'drained and '
#                                                              'sliced into '
#                                                              'large chunks',
#                                                              'drained, '
#                                                              'crumbled',
#                                                              'drained, patted '
#                                                              'dry, and sliced '
#                                                              'into 4 slices',
#                                                              'sliced and well '
#                                                              'drained',
#                                                              'sliced into 1/4 '
#                                                              'inch slices',
#                                                              'sliced into 8 '
#                                                              'even pieces',
#                                                              'undrained'},
#                                                     'tomato': {None,
#                                                                'chopped',
#                                                                'seeded and '
#                                                                'chopped'},
#                                                     'tomato juice': {None},
#                                                     'tomato paste': {None},
#                                                     'tomato sauce': {None},
#                                                     'tomatoes': {None,
#                                                                  'chopped',
#                                                                  'drained, 1/4 '
#                                                                  'cup juice '
#                                                                  'reserved',
#                                                                  'undrained'},
#                                                     'tomatoes with juice': {None},
#                                                     'tortillas': {None},
#                                                     'turbinado sugar': {None},
#                                                     'turmeric': {None},
#                                                     'uncooked sushi (sticky) or medium-grain rice': {None},
#                                                     'vanilla extract': {None},
#                                                     'vegan cream cheese (such as Tofutti)': {None},
#                                                     'vegan mayonnaise': {None},
#                                                     'vegan sausage (optional)': {'cut '
#                                                                                  'into '
#                                                                                  '1/4 '
#                                                                                  'inch '
#                                                                                  'slices'},
#                                                     'vegetables': {None},
#                                                     'vegetarian ground beef substitute': {None},
#                                                     'vinegar': {None},
#                                                     'virgin olive oil': {None},
#                                                     'vital wheat gluten': {None},
#                                                     'water': {None},
#                                                     'water chestnuts': {'drained'},
#                                                     'wheat flour': {None},
#                                                     'wheat hamburger buns': {'split'},
#                                                     'white': {None},
#                                                     'wine': {None},
#                                                     'yeast': {None},
#                                                     'yeast (optional)': {None},
#                                                     'yogurt': {None},
#                                                     'zest': {None},
#                                                     'zucchini': {None,
#                                                                  'cut into '
#                                                                  'large chunks',
#                                                                  'diced'}})}}

# %%
# names with description
# vege_ingredient = ingredients['vegetarian']['ingredients'].keys()
seafood_ingredient = ingredients['seafood']['ingredients']
meat_ingredient = ingredients['meat']['ingredients']
vege_protein_ingredient = ingredients['vegetarian_protein']['ingredients']

# seafood_ingredient = list(seafood_ingredient)
# meat_ingredient = list(meat_ingredient)
# vege_protein_ingredient = list(vege_protein_ingredient)

# noun
# seasonings = ingredients['seasonings']
# seasonings = list(set(seasonings))

# %%
# manually extract meat protein from scrapy result
meat_proteins = {}
meat_protein_list = []
with open('meat_ingredients.txt', 'r') as f:
    for line in f.readlines():
        ingre = line.strip()
        meat_protein_list.append(ingre)
        meat_proteins[ingre] = {}
f.close()


for ingre in meat_proteins:
    if ingre in  ingredients['meat']['measurement']:
        meat_proteins[ingre]['measurement'] = ingredients['meat']['measurement'][ingre]
    if ingre in  ingredients['meat']['descriptor']:
        meat_proteins[ingre]['descriptor'] = ingredients['meat']['descriptor'][ingre]
    if ingre in  ingredients['meat']['preparation']:
        meat_proteins[ingre]['preparation'] = ingredients['meat']['preparation'][ingre]

for ingre in meat_proteins:
    if ingre in  ingredients['seafood']['measurement']:
        meat_proteins[ingre]['measurement'] = ingredients['seafood']['measurement'][ingre]
    if ingre in  ingredients['seafood']['descriptor']:
        meat_proteins[ingre]['descriptor'] = ingredients['seafood']['descriptor'][ingre]
    if ingre in  ingredients['seafood']['preparation']:
        meat_proteins[ingre]['preparation'] = ingredients['seafood']['preparation'][ingre]
        
# for ingredients that not in the scape file, manually add general data
for ingre in list(meat_proteins.keys()):
    if 'measurement' not in meat_proteins[ingre]:
        meat_proteins[ingre]['measurement'] = ['pound']
    if 'descriptor' not in meat_proteins[ingre]:
        meat_proteins[ingre]['descriptor'] = ['fresh', 'raw', None]
    if 'preparation' not in meat_proteins[ingre]:
        meat_proteins[ingre]['preparation'] = ['cut into cubes']
        
        
pprint.pprint(meat_proteins)
# Out:
# {'alligator': {'descriptor': ['fresh', 'raw', None],
#                'measurement': ['pound'],
#                'preparation': ['cut into cubes']},
#  'bacon': {'descriptor': {None,
#                           'cooked',
#                           'thick cut',
#                           'thick sliced',
#                           'thickly sliced'},
#            'measurement': {'slices', 'pound', 'pounds'},
#            'preparation': {None,
#                            'chopped',
#                            'cut in half',
#                            'cut into 1/2 inch pieces',
#                            'diced',
#                            'minced'}},
#  'bass': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'beef': {'descriptor': {'ground', 'lean ground', 'extra lean ground'},
#           'measurement': {'pound', 'pounds'},
#           'preparation': {None}},
#  'belly': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'bison': {'descriptor': {'ground'},
#            'measurement': {'pound'},
#            'preparation': {None}},
#  'boart': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'breast': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'buffalo': {'descriptor': {'ground'},
#              'measurement': {'pound'},
#              'preparation': {None}},
#  'caribou': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'carp': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'catfish': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'chicken': {'descriptor': {'cooked', 'whole'},
#              'measurement': {None, 'cups'},
#              'preparation': {'cut into bite-size pieces',
#                              'cut into pieces',
#                              'giblets removed'}},
#  'chop': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'crayfish': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'deer': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'duck': {'descriptor': {'whole', 'frozen'},
#           'measurement': {None},
#           'preparation': {'dressed', None}},
#  'elk': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'fish': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'frog': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'goat': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'goose': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'guanciale': {'descriptor': ['fresh', 'raw', None],
#                'measurement': ['pound'],
#                'preparation': ['cut into cubes']},
#  'guineafowl': {'descriptor': ['fresh', 'raw', None],
#                 'measurement': ['pound'],
#                 'preparation': ['cut into cubes']},
#  'ham': {'descriptor': {'diced cooked', None},
#          'measurement': {'slices', 'cup'},
#          'preparation': {None}},
#  'lamb': {'descriptor': {'ground', 'lean ground', 'cubed cooked'},
#           'measurement': {'cups', 'pound', 'pounds'},
#           'preparation': {None}},
#  'leg': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'liver': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'lobster': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'meat': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'meatball': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'moose': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'mussel': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'oyster': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'pheasant': {'descriptor': {'pheasant'},
#               'measurement': {None},
#               'preparation': {'deboned, skinned and cut into small chunks'}},
#  'pork': {'descriptor': {'ground'},
#           'measurement': {'pound'},
#           'preparation': {None}},
#  'prawn': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'quail': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'rabbit': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'reindeer': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'rib': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'ribs': {'descriptor': {None},
#           'measurement': {'celery'},
#           'preparation': {'chopped'}},
#  'rump': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'salmon': {'descriptor': {None, 'red'},
#             'measurement': {'fillets', 'can', 'pound'},
#             'preparation': {None, 'skin and bone removed, drained and flaked'}},
#  'sausage': {'descriptor': {'Italian', 'sweet Italian'},
#              'measurement': {'pound'},
#              'preparation': {None,
#                              'casings removed',
#                              'casings removed and crumbled'}},
#  'scallop': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'shanks': {'descriptor': {None},
#             'measurement': {'lamb'},
#             'preparation': {None}},
#  'sheep': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'shoulder': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'shrimp': {'descriptor': {None,
#                            'cooked',
#                            'fresh',
#                            'large',
#                            'medium',
#                            'medium raw'},
#             'measurement': {None, 'ounces', 'pound', 'pounds'},
#             'preparation': {None,
#                             'peeled and deveined',
#                             'shelled, deveined, with tails attached',
#                             'tails removed'}},
#  'skewer': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'skinless': {'descriptor': {None},
#               'measurement': {'pound'},
#               'preparation': {'boneless chicken breast halves, cut into 1 inch '
#                               'cubes'}},
#  'snail': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'steak': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'tenderloin': {'descriptor': {None},
#                 'measurement': {'pork'},
#                 'preparation': {None}},
#  'thigh': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'tilapia': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'tripe': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'trout': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'turkey': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'turtle': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'veal': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'venison': {'descriptor': {None, 'ground'},
#              'measurement': {'pound', 'pounds'},
#              'preparation': {None,
#                              'cut into 1/4 thick strips',
#                              'cut into 2 inch strips',
#                              'cut into cubes'}},
#  'wing': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']}}

# %%
# manually extract vegie protein from scrapy result
vegie_proteins = {}
vegie_protein_list = []
with open('vegie_protein.txt', 'r') as f:
    for line in f.readlines():
        ingre = line.strip()
        vegie_protein_list.append(ingre)
        vegie_proteins[ingre] = {}
f.close()


for ingre in vegie_proteins:
    if ingre in  ingredients['vegetarian_protein']['measurement']:
        vegie_proteins[ingre]['measurement'] = ingredients['vegetarian_protein']['measurement'][ingre]
    else:
        vegie_proteins[ingre]['measurement'] = ['cup', 'can']
    if ingre in  ingredients['vegetarian_protein']['descriptor']:
        vegie_proteins[ingre]['descriptor'] = ingredients['vegetarian_protein']['descriptor'][ingre]
    else:
        vegie_proteins[ingre]['descriptor'] = [None]
    if ingre in  ingredients['vegetarian_protein']['preparation']:
        vegie_proteins[ingre]['preparation'] = ingredients['vegetarian_protein']['preparation'][ingre]
    else:
        vegie_proteins[ingre]['preparation'] = ['drained']
#         print(ingredients['vegetarian_protein']['measurement'][ingre])

print(vegie_protein_list)
pprint.pprint(vegie_proteins)
# Out:
# ['tofu', 'tempeh', 'seitan', 'garbanzo beans', 'chickpeas', 'snow peas', 'kidney beans', 'garden herb tofu']
# {'chickpeas': {'descriptor': [None],
#                'measurement': ['cup', 'can'],
#                'preparation': ['drained']},
#  'garbanzo beans': {'descriptor': [None],
#                     'measurement': ['cup', 'can'],
#                     'preparation': ['drained']},
#  'garden herb tofu': {'descriptor': {None},
#                       'measurement': {'package'},
#                       'preparation': {'crumbled'}},
#  'kidney beans': {'descriptor': {None, 'light red', 'dry'},
#                   'measurement': {'can', 'cup'},
#                   'preparation': {None, 'soaked overnight', 'undrained'}},
#  'seitan': {'descriptor': {'seitan'},
#             'measurement': {'package', 'packages'},
#             'preparation': {None}},
#  'snow peas': {'descriptor': {None},
#                'measurement': {'cups', 'cup'},
#                'preparation': {'trimmed'}},
#  'tempeh': {'descriptor': {None, 'spicy flavored'},
#             'measurement': {'package', 'packages', 'slice'},
#             'preparation': {None,
#                             'broken into bite-sized pieces',
#                             'coarsely grated',
#                             'crumbled'}},
#  'tofu': {'descriptor': {None,
#                          'baked',
#                          'crumbled firm silken',
#                          'extra firm',
#                          'extra-firm',
#                          'firm',
#                          'firm water-packed',
#                          'fried',
#                          'silken',
#                          'soft',
#                          'soft silken',
#                          'thinly sliced firm'},
#           'measurement': {'container',
#                           'cup',
#                           'cups',
#                           'ounces',
#                           'package',
#                           'packages',
#                           'pound',
#                           'pounds'},
#           'preparation': {None,
#                           'crumbled',
#                           'cubed',
#                           'cut into 1-inch cubes',
#                           'cut into 1/4-inch cubes',
#                           'cut into 3/4 inch cubes',
#                           'cut into bite-size pieces',
#                           'cut into bite-sized cubes',
#                           'diced',
#                           'drained',
#                           'drained and cubed',
#                           'drained and cut into cubes',
#                           'drained and cut into strips',
#                           'drained and diced',
#                           'drained and pressed',
#                           'drained and sliced into large chunks',
#                           'drained, crumbled',
#                           'drained, patted dry, and sliced into 4 slices',
#                           'sliced and well drained',
#                           'sliced into 1/4 inch slices',
#                           'sliced into 8 even pieces',
#                           'undrained'}}}

# %%
from collections import defaultdict

import spacy
import requests
from bs4 import BeautifulSoup


import main as utils

# %%
import re
import requests
from bs4 import BeautifulSoup

url = 'https://www.allrecipes.com/recipe/8665/braised-balsamic-chicken/'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# extract ingredients section from the webpage
lines = set([element.label.text.strip() for element in soup.find_all(class_='checkList__line')])
# remove unnecessary elements
lines.remove('')
lines.remove('Add all ingredients to list')
lines

def get_ingredients(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    # extract ingredients section from the webpage
    lines = set([element.label.text.strip() for element in soup.find_all(class_='checkList__line')])
    # remove unnecessary elements
    lines.remove('')
    lines.remove('Add all ingredients to list')
    lines
    return lines

# %%
import random

def get_random(ingres):
    l = len(ingres)
    if l == 0 or (l == 1 and ingres[0] is None):
        return ''
    ran_num = random.randint(0,l-1)
    res = ingres[ran_num]
    
    # handle None type
    if res is None:
        return get_random(ingres)
    else:
        return res

print(get_random(list(vegie_proteins.keys())))
# Out:
# snow peas

# %%
# some special ingredients
special_sub = {
    'frankfurter':'vegetarian sausage',
  'meatball':'vegetarian meatball',
  'meatloaf':'tofu',
  'sausage':'vegetarian sausage',
  'bacon':'vegetarian bacon',
  'ham':'vegetarian ham',
  'skewer':'tofu skewer'}

def get_vegie_substitution(ingre):
    sub = ''
    if 'stock' in ingre or 'consomme' in ingre or 'bouillon' in ingre:
        sub = 'vegetable stock'
    elif 'broth' in ingre:
        sub = 'vegetable broth'
    else:           
        for meat in list(special_sub.keys()):
            if meat in ingre or ingre in meat:
                sub = special_sub[meat]
    if sub == '':
        # choose a random vegie protein
        sub = get_random(vegie_protein_list)
    return sub
    
def get_meat_substitution(ingre):
    if is_broth(ingre):
        return 'chicken broth'
    for meat in list(special_sub.keys()):
        if meat in ingre or ingre in meat:
            return meat
    return get_random(meat_protein_list)

# %%
def is_broth(ingre):
     if 'stock' in ingre or 'consomme' in ingre or 'bouillon' in ingre or  'broth' in ingre:
        return True
     return False

def is_meat(ingre):
    for meat in meat_protein_list:
        if meat in ingre or ingre in meat:
            return True
    if is_broth(ingre) is True:
        return True
    else:
        return False
    return False

def is_vegie_protein(ingre):
    for i in vegie_protein_list:
        if i in ingre or ingre in i:
            return True
    if is_broth(ingre) is True:
        return True
#     if 'stock' in ingre or 'consomme' in ingre or 'bouillon' in ingre or  'broth' in ingre:
#         return True
    return False

# %% [markdown]
# # To Vegetarian

# %%
res = []
url = 'https://www.allrecipes.com/recipe/219763/chicken-marsala-over-white-rice/'
# lines = get_ingredients(url)
recipe = utils.Recipe(url)

# %%
# go through the directions first to get a substitution dict
directions = recipe.directions
sub_dict = {}

for direction in directions:
#     print(direction)
    single_direction_ingredients = recipe.extract_ingredients(direction)
    for ingre in single_direction_ingredients:
        if is_meat(ingre) is True and ingre not in sub_dict.keys():
            sub = get_vegie_substitution(ingre)
            sub_dict[ingre] = sub
print(sub_dict)
# Out:
# {'chicken': 'garden herb tofu', 'chicken stock': 'vegetable stock'}

# %%
for line in recipe.ingredients:
    quantity, measurement, descriptor, ingredient, preparation = recipe.extract_all(line)
        
    if is_meat(ingredient) is True:
        sub = ''
        for key in list(sub_dict.keys()):
            if key in ingredient or ingredient in key:
                sub = sub_dict[key]
        if sub == '':
            sub = get_vegie_substitution(ingredient)
            sub_dict[ingredient] = sub
            
        if is_broth(ingredient) is True:
            sub_measurement = measurement
            sub_preparation = '' if preparation else ''
            sub_descriptor = '' if descriptor else ''
            
        else:
            sub_measurement = get_random(list(vegie_proteins[sub]['measurement']))
            sub_preparation = get_random(list(vegie_proteins[sub]['preparation']))
            sub_descriptor = get_random(list(vegie_proteins[sub]['descriptor']))
            
        replacement = quantity+' '+sub_measurement+' '+sub_descriptor+' '+sub
        print('REPLACE')
        print(line)
        print('TO')
        print(replacement)
    else:
        print(line)
    print('----------------------------')
        

print(sub_dict)
# Out:
# 1 cup all-purpose flour
# ----------------------------
# 1 pinch dried oregano to taste
# ----------------------------
# ground black pepper to taste
# ----------------------------
# REPLACE
# 1/2 cup chicken stock
# TO
# 1/2 cup  vegetable stock
# ----------------------------
# 1 cup sliced fresh mushrooms
# ----------------------------
# 2 tablespoons butter, divided
# ----------------------------
# salt to taste
# ----------------------------
# 1 clove garlic, minced
# ----------------------------
# 1/2 cup Marsala wine
# ----------------------------
# 1 cup uncooked white rice
# ----------------------------
# salt and ground black pepper to taste
# ----------------------------
# REPLACE
# 1 pound skinless, boneless chicken cutlets, pounded to 1/4-inch thickness
# TO
# 1 packages seitan seitan
# ----------------------------
# 2 cups water
# ----------------------------
# 1 tablespoon olive oil
# ----------------------------
# {'chicken': 'garden herb tofu', 'chicken stock': 'vegetable stock', 'skinless': 'seitan'}

# %%
for direction in directions:
    new_direction = direction
    for key in list(sub_dict.keys()):
            if key in direction:
                new_direction = new_direction.replace(key, sub_dict[key])
                
    # go over the meat ingredient in case words like 'breast' / 'chop' show up
    for word in new_direction.split():
        for meat in meat_protein_list:
            if word == meat or meat+'s' == word:
                new_direction = new_direction.replace(word, '')
                
    print('-----------------------------------------------------------')
    if direction != new_direction:
        print('REPLACE')
        print(direction)
        print('TO')
        print(new_direction)
    else:
        print(direction)
# Out:
# -----------------------------------------------------------
# Bring the rice and water to a boil in a saucepan over high heat. Reduce heat to medium-low, cover, and simmer until the rice is tender, and the liquid has been absorbed, 20 to 25 minutes. Set rice aside.
# -----------------------------------------------------------
# REPLACE
# In a large bowl, whisk the flour with salt, black pepper, and oregano. Gently press the chicken breasts into the flour mixture to coat, and shake off the excess flour.
# TO
# In a large bowl, whisk the flour with salt, black pepper, and oregano. Gently press the garden herb tofu  into the flour mixture to coat, and shake off the excess flour.
# -----------------------------------------------------------
# REPLACE
# Heat the olive oil and 1 tablespoon butter in a large skillet over medium-high heat. Arrange the chicken in the skillet and cook until the chicken is no longer pink inside and golden brown outside, 5 to 8 minutes per side. Drain the cooked chicken on a paper towel-lined plate.
# TO
# Heat the olive oil and 1 tablespoon butter in a large skillet over medium-high heat. Arrange the garden herb tofu in the skillet and cook until the garden herb tofu is no longer pink inside and golden brown outside, 5 to 8 minutes per side. Drain the cooked garden herb tofu on a paper towel-lined plate.
# -----------------------------------------------------------
# REPLACE
# Melt the remaining 1 tablespoon butter in the same skillet over medium heat while scraping up any brown bits with a spoon. Stir in the garlic; cook and stir until fragrant. Add the mushrooms, and cook and stir until they are tender and have released their liquid, about 10 minutes. Season with salt and black pepper, then stir in the Marsala wine and chicken stock.
# TO
# Melt the remaining 1 tablespoon butter in the same skillet over medium heat while scraping up any brown bits with a spoon. Stir in the garlic; cook and stir until fragrant. Add the mushrooms, and cook and stir until they are tender and have released their liquid, about 10 minutes. Season with salt and black pepper, then stir in the Marsala wine and garden herb tofu stock.
# -----------------------------------------------------------
# REPLACE
# Transfer the chicken back to the skillet, and spoon sauce over chicken pieces. Increase heat to medium-high, and bring to a boil. Cover, reduce heat to medium-low, and simmer until the the sauce is thickened, about 5 minutes more. Serve the chicken and sauce over the cooked rice.
# TO
# Transfer the garden herb tofu back to the skillet, and spoon sauce over garden herb tofu pieces. Increase heat to medium-high, and bring to a boil. Cover, reduce heat to medium-low, and simmer until the the sauce is thickened, about 5 minutes more. Serve the garden herb tofu and sauce over the cooked rice.

# %% [markdown]
# # To Non-Vegetarian

# %%
url = 'https://www.allrecipes.com/recipe/246141/pad-thai-with-tofu/'
lines = get_ingredients(url)
recipe = utils.Recipe(url)

# %%
directions = recipe.directions
sub_dict = {}

for direction in directions:
#     print(direction)
    single_direction_ingredients = recipe.extract_ingredients(direction)
    for ingre in single_direction_ingredients:
        if is_vegie_protein(ingre) is True and ingre not in sub_dict.keys():
            sub = get_meat_substitution(ingre)
            sub_dict[ingre] = sub
print(sub_dict)
# Out:
# {'tofu': 'alligator'}

# %%
for line in recipe.ingredients:
    quantity, measurement, descriptor, ingredient, preparation = recipe.extract_all(line)
    
    if is_vegie_protein(ingredient) is True:
        sub = ''
        for key in list(sub_dict.keys()):
            if key in ingredient or ingredient in key:
                sub = sub_dict[key]
        if sub == '':
            sub = get_meat_substitution(ingredient)
            sub_dict[ingredient] = sub
            
        if is_broth(ingredient) is True:
            sub_measurement = measurement
            sub_preparation = '' if preparation else ''
            sub_descriptor = '' if descriptor else ''
            
        else:
            sub_measurement = get_random(list(meat_proteins[sub]['measurement']))
            sub_preparation = get_random(list(meat_proteins[sub]['preparation']))
            sub_descriptor = get_random(list(meat_proteins[sub]['descriptor']))
            
        replacement = quantity+' '+sub_measurement+' '+sub_descriptor+' '+sub
        print('REPLACE')
        print(line)
        print('TO')
        print(replacement)
    else:
        print(line)
    print('----------------------------')
        

print(sub_dict)
# Out:
# 1/4 cup soy sauce
# ----------------------------
# 1 teaspoon red pepper flakes
# ----------------------------
# 1 tablespoon tamarind concentrate
# ----------------------------
# 1 egg (optional)
# ----------------------------
# 1 lime, cut into wedges
# ----------------------------
# 3 tablespoons vegetable oil, divided
# ----------------------------
# REPLACE
# 1 (12 ounce) package tofu, drained and cubed
# TO
# 1 (12 ounce) pound raw alligator
# ----------------------------
# 2 tablespoons white sugar
# ----------------------------
# 1 tablespoon cornstarch
# ----------------------------
# 2 tablespoons chopped spring onions
# ----------------------------
# 8 ounces dry rice stick noodles
# ----------------------------
# 1 tablespoon crushed peanuts
# ----------------------------
# Sauce:
# ----------------------------
# 1/2 onion, sliced
# ----------------------------
# 1/4 cup water
# ----------------------------
# 1/4 cup sriracha hot sauce
# ----------------------------
# {'tofu': 'alligator'}

# %%
for direction in directions:
    new_direction = direction
    for key in list(sub_dict.keys()):
            if key in direction:
                new_direction = new_direction.replace(key, sub_dict[key])
    for word in new_direction.split():
        for meat in vegie_protein_list:
            if word == meat or meat+'s' == word:
                new_direction = new_direction.replace(word, '')
    print('-----------------------------------------------------------')
    if direction != new_direction:
        print('REPLACE')
        print(direction)
        print('TO')
        print(new_direction)
    else:
        print(direction)
