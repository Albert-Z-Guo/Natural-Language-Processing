# %%
import pickle
import random
import pprint

# add parent directory
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)

from recipe import Recipe

# %%
# load scraped data:
# 4 pages of vegetarian protein recipes
# 6 pages of meat recipes
# 2 pages of seafood recipes

with open('../data/ingredients_categorized.pickle', 'rb') as file:
    ingredients_categorized = pickle.load(file)
file.close()

pprint.pprint(ingredients_categorized)
# Out:
# {'meat': {'descriptor': defaultdict(<class 'set'>,
#                                     {'Cajun seasoning': {None},
#                                      'Cheddar cheese': {'shredded',
#                                                         'shredded sharp',
#                                                         'shredded, optional'},
#                                      'Colby cheese': {None},
#                                      'Dijon mustard': {None},
#                                      'MEATBALLS': {None},
#                                      'Marsala wine': {None},
#                                      'Parmesan cheese': {None},
#                                      'Pecorino Romano cheese': {None},
#                                      'Ranch dressing': {None},
#                                      'SAUCE': {None},
#                                      'San Marzano tomatoes': {None},
#                                      'Scotch': {'thinly sliced fillet, chuck '
#                                                 'eye steaks'},
#                                      'Worcestershire sauce': {None},
#                                      'Yukon Gold potatoes and': {'peeled '
#                                                                  'halved'},
#                                      'allspice': {'ground'},
#                                      'and': {'parsnip peeled diced'},
#                                      'and potatoes': {None},
#                                      'andouille sausage': {None},
#                                      'angel hair pasta': {None},
#                                      'apple': {'large'},
#                                      'apple cider': {None},
#                                      'apple cider vinegar': {None},
#                                      'apples': {'tart'},
#                                      'bacon': {None,
#                                                'cooked',
#                                                'thick cut',
#                                                'thick sliced',
#                                                'thickly sliced'},
#                                      'bacon bits': {None},
#                                      'barbecue sauce': {None},
#                                      'barley': {None},
#                                      'base': {'concentrated vegetable, such as '
#                                               'Swanson® Vegetable Flavor '
#                                               'Boost®, optional'},
#                                      'basil': {'dried'},
#                                      'basil leaves': {'dried',
#                                                       'packed fresh',
#                                                       'very thinly sliced '
#                                                       'fresh'},
#                                      'bay leaf': {'ground'},
#                                      'beans': {'black',
#                                                'cut green',
#                                                'great Northern',
#                                                'green',
#                                                'refried'},
#                                      'beef': {'extra lean ground',
#                                               'ground',
#                                               'lean ground'},
#                                      'beef bouillon': {None},
#                                      'beef broth': {None},
#                                      'beef chuck': {'ground', 'boneless'},
#                                      'beef consomme': {None},
#                                      'beef meat': {'cubed stew', 'stew'},
#                                      'beef meat)': {'stew'},
#                                      'beef rib roast': {None},
#                                      'beef sirloin': {None},
#                                      'beef stock': {None},
#                                      'beef tips': {None},
#                                      'beer': {None,
#                                               'Irish stout, such as Guinness®'},
#                                      'bell pepper': {'chopped green',
#                                                      'chopped red',
#                                                      'diced green',
#                                                      'green',
#                                                      'large green',
#                                                      'medium red',
#                                                      'medium yellow',
#                                                      'red'},
#                                      'bell peppers': {'large green'},
#                                      'biscuit dough': {'refrigerated'},
#                                      'biscuits': {'refrigerated flaky-style, '
#                                                   'such as Pillsbury Grands®'},
#                                      'bison': {'ground'},
#                                      'boiling water': {None},
#                                      'bow tie pasta': {None},
#                                      'bread': {None, 'multigrain'},
#                                      'bread crumbs': {None,
#                                                       'Italian seasoned',
#                                                       'Italian-seasoned',
#                                                       'Italian-style seasoned',
#                                                       'dried',
#                                                       'dry',
#                                                       'fresh',
#                                                       'seasoned'},
#                                      'bread rounds': {None},
#                                      'broccoli florets': {None},
#                                      'bucatini pasta': {None},
#                                      'buffalo': {'ground'},
#                                      'buffalo meat': {'ground'},
#                                      'bulk sausage': {'Italian',
#                                                       'mild Italian'},
#                                      'buns': {None},
#                                      'butter': {'unsalted', 'melted', None},
#                                      'butternut': {'small squash'},
#                                      'cabbage': {None},
#                                      'canola oil': {None},
#                                      'cardamom': {'ground'},
#                                      'carrot': {'small', None},
#                                      'carrots': {None,
#                                                  'diced',
#                                                  'frozen cut',
#                                                  'large',
#                                                  'medium',
#                                                  'sliced',
#                                                  'thinly sliced'},
#                                      'cayenne pepper': {'ground', None},
#                                      'celery': {None,
#                                                 'chopped',
#                                                 'diced',
#                                                 'sliced'},
#                                      'celery salt': {None},
#                                      'celery seed': {None},
#                                      'cheese': {'Irish, such as Dubliner®',
#                                                 'Swiss',
#                                                 'crumbled feta',
#                                                 'feta',
#                                                 'ricotta'},
#                                      'chicken': {'cooked',
#                                                  'shredded cooked',
#                                                  'whole'},
#                                      'chicken bouillon granules': {None},
#                                      'chicken breast halves': {'boneless '
#                                                                'skinless',
#                                                                'frozen '
#                                                                'skinless '
#                                                                'boneless',
#                                                                'skinless '
#                                                                'boneless'},
#                                      'chicken breast meat': {'cubed cooked'},
#                                      'chicken breasts': {'boneless skinless',
#                                                          'whole skinless '
#                                                          'boneless'},
#                                      'chicken broth': {None,
#                                                        'condensed',
#                                                        'low-sodium',
#                                                        'lower-sodium'},
#                                      'chicken broth or broth': {None},
#                                      'chicken cutlets': {'skinless boneless'},
#                                      'chicken stock': {None},
#                                      'chicken thighs': {'skinless',
#                                                         'skinless boneless'},
#                                      'chickens': {'whole'},
#                                      'chile pepper': {None, 'diced green'},
#                                      'chile peppers': {'chopped green',
#                                                        'green'},
#                                      'chiles': {'diced green',
#                                                 'diced green, optional'},
#                                      'chili beans': {None},
#                                      'chili beans in sauce': {None},
#                                      'chili peppers': {'diced green'},
#                                      'chili powder': {None},
#                                      'chili seasoning mix': {None},
#                                      'chilies': {'minced Thai'},
#                                      'chipotle pepper': {'dried'},
#                                      'chopped fresh rosemary': {'chopped fresh '
#                                                                 'rosemary'},
#                                      'chops': {None},
#                                      'chunk chicken': {None},
#                                      'chutney': {'finely chopped'},
#                                      'cider vinegar': {None},
#                                      'cilantro': {'chopped',
#                                                   'chopped fresh',
#                                                   'chopped, optional',
#                                                   'fresh'},
#                                      'cilantro chutney': {'spicy'},
#                                      'cinnamon': {'ground'},
#                                      'cloves': {'ground', None},
#                                      'cloves garlic': {'large'},
#                                      'cocoa powder': {'unsweetened'},
#                                      'coconut milk': {None},
#                                      'coconut oil': {None},
#                                      'cooking oats': {'quick'},
#                                      'cooking sherry': {None},
#                                      'cooking spray': {None},
#                                      'cooking wine': {None},
#                                      'coriander': {'ground'},
#                                      'corn': {'frozen', 'cream-style'},
#                                      'corn chips such as Fritos®': {None},
#                                      'cornstarch': {None, 'optional'},
#                                      'cracker crumbs': {'finely crushed '
#                                                         'saltine'},
#                                      'crackers': {'chicken-flavored',
#                                                   'crushed buttery round'},
#                                      'cream': {'half-and-half',
#                                                'heavy',
#                                                'sour',
#                                                'sour, optional'},
#                                      'cream cheese': {None},
#                                      'cream cheese with chives': {None},
#                                      'cream of chicken soup': {None},
#                                      'cream of mushroom soup': {None},
#                                      'cream of potato soup': {None},
#                                      'cumin': {'ground', None},
#                                      'currant': {'jelly'},
#                                      'curry powder': {None},
#                                      'deer chops': {'venison'},
#                                      'dried rosemary': {'dried rosemary'},
#                                      'dried rosemary crushed': {'dried '
#                                                                 'rosemary '
#                                                                 'crushed'},
#                                      'drops pepper sauce': {None},
#                                      'duck': {'frozen', 'whole'},
#                                      'egg': {None},
#                                      'egg noodles': {'uncooked'},
#                                      'eggs': {None, 'hard-cooked', 'large'},
#                                      'elbow macaroni': {None},
#                                      'elk loin': {'backstrap'},
#                                      'elk meat': {None},
#                                      'fennel seeds': {None},
#                                      'fish sauce': {None},
#                                      'florets': {'cauliflower'},
#                                      'flour': {'all-purpose'},
#                                      'flour for coating': {None},
#                                      'fresh rosemary': {'fresh rosemary'},
#                                      'fusilli pasta': {'spiral'},
#                                      'garam masala': {None},
#                                      'garbanzo beans': {None},
#                                      'garlic': {None,
#                                                 'chopped',
#                                                 'crushed',
#                                                 'minced'},
#                                      'garlic cloves': {'crushed'},
#                                      'garlic powder': {None,
#                                                        'such as McCormick® '
#                                                        'California Style'},
#                                      'garlic salt': {None},
#                                      'giardiniera': {'chopped, pickled Italian '
#                                                      'vegetables'},
#                                      'ginger': {'ground', 'freshly grated'},
#                                      'ginger root': {'chopped fresh',
#                                                      'fresh',
#                                                      'grated fresh'},
#                                      'ground dried rosemary': {'ground dried '
#                                                                'rosemary'},
#                                      'ground nutmeg': {'ground nutmeg'},
#                                      'ground veal': {'ground veal'},
#                                      'guanciale': {'cured pork cheek'},
#                                      'ham': {None,
#                                              'cooked diced',
#                                              'diced cooked'},
#                                      'hamburger buns': {'large'},
#                                      'hash potatoes': {'frozen brown'},
#                                      'honey': {None},
#                                      'in rounds': {'orange sliced'},
#                                      'jalapeno pepper slices': {None},
#                                      'juice': {'fresh unsweetened pomegranate'},
#                                      'kernel corn': {'drained', None},
#                                      'ketchup': {None},
#                                      'kidney beans': {None,
#                                                       'dark red',
#                                                       'light red'},
#                                      'lamb': {'cubed cooked',
#                                               'ground',
#                                               'lean ground'},
#                                      'lamb chops': {None},
#                                      'lamb meat': {None, 'cubed', 'stew'},
#                                      'lamb shoulder': {'boneless'},
#                                      'leaf': {None},
#                                      'leaves': {None},
#                                      'leg of lamb': {None},
#                                      'lemon': {None},
#                                      'lemon juice': {None},
#                                      'lemon wedges': {'fresh, optional'},
#                                      'lemon zest': {None},
#                                      'lemons': {None},
#                                      'lentils': {'green'},
#                                      'lime juice': {'fresh', None},
#                                      'loin chops': {'1-inch thick'},
#                                      'luncheon meat': {'fully cooked, such as '
#                                                        'SPAM®'},
#                                      'margarine': {None},
#                                      'marjoram': {'dried'},
#                                      'mayonnaise': {None},
#                                      'milk': {None, 'skim'},
#                                      'minced fresh rosemary': {'minced fresh '
#                                                                'rosemary'},
#                                      'mint leaves': {'chopped fresh', None},
#                                      'mirin': {'Japanese sweet wine'},
#                                      'molasses': {None},
#                                      'mozzarella cheese': {None},
#                                      'mushroom soup': {'condensed golden'},
#                                      'mushrooms': {'fresh',
#                                                    'sliced',
#                                                    'sliced fresh'},
#                                      'mustard': {'prepared',
#                                                  'prepared Dijon-style',
#                                                  'prepared yellow'},
#                                      'mustard powder': {'dry', None},
#                                      'noodles': {None},
#                                      'oil': {'vegetable'},
#                                      'oil for frying': {None},
#                                      'olive oil': {'extra-virgin', None},
#                                      'olives': {'Spanish-style',
#                                                 'black',
#                                                 'chopped black',
#                                                 'chopped green'},
#                                      'onion': {None,
#                                                'chopped',
#                                                'chopped yellow',
#                                                'diced',
#                                                'extra large',
#                                                'extra-large Spanish',
#                                                'finely chopped',
#                                                'finely minced',
#                                                'grated',
#                                                'large',
#                                                'large yellow',
#                                                'medium',
#                                                'minced',
#                                                'red',
#                                                'sliced red',
#                                                'small',
#                                                'small red',
#                                                'thinly sliced'},
#                                      'onion powder': {None},
#                                      'onion salt': {None},
#                                      'onion soup': {'condensed French'},
#                                      'onion soup mix': {'dry'},
#                                      'onion)': {'medium red'},
#                                      'onions': {None,
#                                                 'chopped green',
#                                                 'green',
#                                                 'large',
#                                                 'large yellow',
#                                                 'medium',
#                                                 'small'},
#                                      'or bottle beer': {None},
#                                      'or bottle root beer': {None},
#                                      'or pepper or to taste': {None},
#                                      'or porter': {None},
#                                      'oregano': {'chopped fresh',
#                                                  'crumbled dried',
#                                                  'dried'},
#                                      'oyster sauce': {None},
#                                      'pan drippings from rib': {None},
#                                      'paprika': {None, 'smoked'},
#                                      'parsley': {'chopped fresh',
#                                                  'chopped fresh flat-leaf',
#                                                  'dried',
#                                                  'fresh',
#                                                  'minced flat-leaf',
#                                                  'minced fresh'},
#                                      'parsnips': {'peeled sliced'},
#                                      'partridge breast halves': {None},
#                                      'pears': {None},
#                                      'peas': {'frozen green', None, 'frozen'},
#                                      'peas and carrots': {'thawed'},
#                                      'pecans': {'optional'},
#                                      'peeled seeded': {'peeled seeded'},
#                                      'pepper': {None,
#                                                 'black',
#                                                 'freshly ground black',
#                                                 'ground black',
#                                                 'ground white',
#                                                 'white'},
#                                      'pepper flakes': {'red', 'crushed red'},
#                                      'pepper sauce': {'hot',
#                                                       'hot, e.g. Tabasco™',
#                                                       "hot, such as Frank's "
#                                                       'RedHot®',
#                                                       'hot, such as Tabasco®',
#                                                       "such as Frank's Red "
#                                                       'Hot®'},
#                                      'peppercorns': {'black'},
#                                      'phyllo dough': {None},
#                                      'pie crusts': {'unbaked'},
#                                      'pinto beans': {None},
#                                      'pinto beans and': {'drained rinsed'},
#                                      'pita breads': {None},
#                                      'pizza crust dough': {None},
#                                      'plum jam': {None},
#                                      'plum tomatoes': {'Italian-style'},
#                                      'plum wine': {'Asian'},
#                                      'pork': {'ground'},
#                                      'pork belly': {'whole'},
#                                      'pork chops': {'thick'},
#                                      'pork loin roast': {'boneless'},
#                                      'pork ribs': {'boneless'},
#                                      'pork sausage': {'spicy ground'},
#                                      'pork shoulder': {None},
#                                      'pork shoulder roast': {'boneless',
#                                                              'butt roast'},
#                                      'port wine': {None},
#                                      'pot roast': {None},
#                                      'potatoes': {None,
#                                                   'large',
#                                                   'mashed boiled',
#                                                   'peeled chopped sweet',
#                                                   'prepared mashed',
#                                                   'red',
#                                                   'small'},
#                                      'provolone cheese': {None},
#                                      'pureed chipotle peppers in adobo sauce': {None},
#                                      'rabbit meat and into pieces': {'cleaned '
#                                                                      'cut'},
#                                      'rack baby pork ribs': {None},
#                                      'rack of lamb and': {'trimmed frenched'},
#                                      'ranch dressing': {None},
#                                      'ribs': {None,
#                                               'Korean-style short, beef chuck '
#                                               'flanken'},
#                                      'rice': {'cooked white',
#                                               'hot cooked',
#                                               'uncooked white'},
#                                      'roast': {None},
#                                      'rolls': {None, 'French'},
#                                      'rump roast': {None},
#                                      'rutabaga': {'small'},
#                                      'saffron': {None},
#                                      'sage': {'dried'},
#                                      'salad dressing': {'Italian'},
#                                      'salad dressing mix': {None},
#                                      'salsa': {None},
#                                      'salt': {'kosher', 'seasoned', None},
#                                      'salt and pepper': {None},
#                                      'salt and pepper or to taste': {None},
#                                      'sauce': {'barbeque',
#                                                'enchilada',
#                                                'hot',
#                                                'hot, such as Louisiana®'},
#                                      'sausage': {'Italian', 'sweet Italian'},
#                                      'savory': {'dried'},
#                                      'sazon seasoning': {'such as Badia® '
#                                                          'Tropical®'},
#                                      'sea salt': {None, 'coarse'},
#                                      'seasoning': {None},
#                                      'seasoning or to taste': {None},
#                                      'seasoning salt': {None},
#                                      'seeds': {'pomegranate'},
#                                      'sesame oil': {None},
#                                      'sesame seeds': {None},
#                                      'shallots': {None,
#                                                   'finely chopped',
#                                                   'minced',
#                                                   'sliced'},
#                                      'shanks': {None},
#                                      'sherry': {None},
#                                      'shoulder roast': {None},
#                                      'shrimp without tails': {None},
#                                      'size flour tortillas': {None},
#                                      'skewers': {None},
#                                      'smoke flavoring': {'liquid'},
#                                      'smokie sausages': {'little'},
#                                      'soy sauce': {None, 'reduced-sodium'},
#                                      'spaghetti sauce': {None},
#                                      'spinach': {'fresh', None},
#                                      'sprig': {None},
#                                      'sriracha sauce': {None},
#                                      'steak sauce': {None},
#                                      'steak seasoning or to taste': {None},
#                                      'steak seasoning rub': {None},
#                                      'sticks': {None},
#                                      'sugar': {None,
#                                                'brown',
#                                                'dark brown',
#                                                'light brown',
#                                                'packed brown',
#                                                'white'},
#                                      'sugar)': {'white'},
#                                      'taco sauce': {None},
#                                      'taco seasoning': {None},
#                                      'taco seasoning mix': {None},
#                                      'tarragon': {'dried'},
#                                      'tenderloin': {None},
#                                      'thyme': {'chopped fresh',
#                                                'dried',
#                                                'fresh',
#                                                'ground',
#                                                'ground dried'},
#                                      'tomato juice': {None},
#                                      'tomato paste': {'sun-dried', None},
#                                      'tomato sauce': {'canned', None},
#                                      'tomato soup': {None, 'condensed'},
#                                      'tomatoes': {None,
#                                                   'Italian-style stewed',
#                                                   'canned diced',
#                                                   'crushed',
#                                                   'diced',
#                                                   'large',
#                                                   'petite diced',
#                                                   'stewed',
#                                                   'stewed diced',
#                                                   'whole peeled'},
#                                      'tomatoes with chile peppers': {None},
#                                      'tomatoes with chiles': {None},
#                                      'tomatoes with chilies': {'undrained'},
#                                      'tomatoes with juice': {None, 'chopped'},
#                                      'toothpicks': {None},
#                                      'tortellini pasta': {'fresh'},
#                                      'tortilla chips': {'crushed, optional'},
#                                      'tortillas': {None},
#                                      'turmeric': {'ground'},
#                                      'turmeric powder': {None},
#                                      'venison': {'ground', None},
#                                      'venison backstrap': {None},
#                                      'venison meat': {'stew'},
#                                      'venison roast': {'boneless'},
#                                      'venison steaks': {None},
#                                      'venison tenderloin': {None},
#                                      'vermicelli pasta': {None},
#                                      'vinegar': {'aged balsamic',
#                                                  'balsamic',
#                                                  'distilled white',
#                                                  'white'},
#                                      'water': {'cold', 'hot', None, 'optional'},
#                                      'wedges': {None},
#                                      'whipping cream': {None},
#                                      'wine': {'dry red',
#                                               'dry white',
#                                               'red',
#                                               'white'},
#                                      'wine vinegar': {'white', 'red', None},
#                                      'yogurt': {'plain'},
#                                      'yolk': {None},
#                                      'your barbecue sauce': {None},
#                                      'ziti pasta': {'dry'},
#                                      'zucchini': {'small', None, 'sliced'}}),
#           'ingredients': {'Cajun seasoning': 1,
#                           'Cheddar cheese': 11,
#                           'Colby cheese': 1,
#                           'Dijon mustard': 2,
#                           'MEATBALLS': 1,
#                           'Marsala wine': 2,
#                           'Parmesan cheese': 10,
#                           'Pecorino Romano cheese': 1,
#                           'Ranch dressing': 1,
#                           'SAUCE': 1,
#                           'San Marzano tomatoes': 1,
#                           'Scotch': 1,
#                           'Worcestershire sauce': 22,
#                           'Yukon Gold potatoes and': 1,
#                           'allspice': 3,
#                           'and': 1,
#                           'and potatoes': 2,
#                           'andouille sausage': 1,
#                           'angel hair pasta': 1,
#                           'apple': 1,
#                           'apple cider': 1,
#                           'apple cider vinegar': 2,
#                           'apples': 1,
#                           'bacon': 12,
#                           'bacon bits': 2,
#                           'barbecue sauce': 1,
#                           'barley': 1,
#                           'base': 1,
#                           'basil': 10,
#                           'basil leaves': 4,
#                           'bay leaf': 1,
#                           'beans': 6,
#                           'beef': 20,
#                           'beef bouillon': 6,
#                           'beef broth': 13,
#                           'beef chuck': 3,
#                           'beef consomme': 1,
#                           'beef meat': 3,
#                           'beef meat)': 1,
#                           'beef rib roast': 1,
#                           'beef sirloin': 1,
#                           'beef stock': 2,
#                           'beef tips': 1,
#                           'beer': 3,
#                           'bell pepper': 15,
#                           'bell peppers': 1,
#                           'biscuit dough': 1,
#                           'biscuits': 1,
#                           'bison': 1,
#                           'boiling water': 2,
#                           'bow tie pasta': 1,
#                           'bread': 2,
#                           'bread crumbs': 11,
#                           'bread rounds': 1,
#                           'broccoli florets': 1,
#                           'bucatini pasta': 1,
#                           'buffalo': 1,
#                           'buffalo meat': 1,
#                           'bulk sausage': 3,
#                           'buns': 4,
#                           'butter': 24,
#                           'butternut': 1,
#                           'cabbage': 1,
#                           'canola oil': 2,
#                           'cardamom': 1,
#                           'carrot': 2,
#                           'carrots': 15,
#                           'cayenne pepper': 19,
#                           'celery': 15,
#                           'celery salt': 2,
#                           'celery seed': 1,
#                           'cheese': 8,
#                           'chicken': 4,
#                           'chicken bouillon granules': 4,
#                           'chicken breast halves': 16,
#                           'chicken breast meat': 1,
#                           'chicken breasts': 2,
#                           'chicken broth': 16,
#                           'chicken broth or broth': 1,
#                           'chicken cutlets': 1,
#                           'chicken stock': 2,
#                           'chicken thighs': 3,
#                           'chickens': 2,
#                           'chile pepper': 4,
#                           'chile peppers': 3,
#                           'chiles': 2,
#                           'chili beans': 4,
#                           'chili beans in sauce': 2,
#                           'chili peppers': 1,
#                           'chili powder': 15,
#                           'chili seasoning mix': 1,
#                           'chilies': 1,
#                           'chipotle pepper': 1,
#                           'chopped fresh rosemary': 4,
#                           'chops': 9,
#                           'chunk chicken': 1,
#                           'chutney': 1,
#                           'cider vinegar': 2,
#                           'cilantro': 9,
#                           'cilantro chutney': 1,
#                           'cinnamon': 8,
#                           'cloves': 3,
#                           'cloves garlic': 1,
#                           'cocoa powder': 1,
#                           'coconut milk': 1,
#                           'coconut oil': 1,
#                           'cooking oats': 1,
#                           'cooking sherry': 2,
#                           'cooking spray': 1,
#                           'cooking wine': 1,
#                           'coriander': 6,
#                           'corn': 2,
#                           'corn chips such as Fritos®': 2,
#                           'cornstarch': 5,
#                           'cracker crumbs': 1,
#                           'crackers': 2,
#                           'cream': 12,
#                           'cream cheese': 5,
#                           'cream cheese with chives': 1,
#                           'cream of chicken soup': 2,
#                           'cream of mushroom soup': 6,
#                           'cream of potato soup': 1,
#                           'cumin': 22,
#                           'currant': 1,
#                           'curry powder': 1,
#                           'deer chops': 1,
#                           'dried rosemary': 5,
#                           'dried rosemary crushed': 1,
#                           'drops pepper sauce': 1,
#                           'duck': 3,
#                           'egg': 10,
#                           'egg noodles': 1,
#                           'eggs': 9,
#                           'elbow macaroni': 1,
#                           'elk loin': 1,
#                           'elk meat': 1,
#                           'fennel seeds': 2,
#                           'fish sauce': 1,
#                           'florets': 1,
#                           'flour': 20,
#                           'flour for coating': 1,
#                           'fresh rosemary': 1,
#                           'fusilli pasta': 1,
#                           'garam masala': 2,
#                           'garbanzo beans': 1,
#                           'garlic': 64,
#                           'garlic cloves': 1,
#                           'garlic powder': 25,
#                           'garlic salt': 7,
#                           'giardiniera': 1,
#                           'ginger': 10,
#                           'ginger root': 3,
#                           'ground dried rosemary': 2,
#                           'ground nutmeg': 3,
#                           'ground veal': 1,
#                           'guanciale': 1,
#                           'ham': 4,
#                           'hamburger buns': 1,
#                           'hash potatoes': 1,
#                           'honey': 6,
#                           'in rounds': 1,
#                           'jalapeno pepper slices': 1,
#                           'juice': 1,
#                           'kernel corn': 2,
#                           'ketchup': 14,
#                           'kidney beans': 5,
#                           'lamb': 11,
#                           'lamb chops': 1,
#                           'lamb meat': 3,
#                           'lamb shoulder': 2,
#                           'leaf': 8,
#                           'leaves': 5,
#                           'leg of lamb': 1,
#                           'lemon': 4,
#                           'lemon juice': 7,
#                           'lemon wedges': 1,
#                           'lemon zest': 3,
#                           'lemons': 1,
#                           'lentils': 1,
#                           'lime juice': 2,
#                           'loin chops': 1,
#                           'luncheon meat': 1,
#                           'margarine': 2,
#                           'marjoram': 3,
#                           'mayonnaise': 3,
#                           'milk': 13,
#                           'minced fresh rosemary': 2,
#                           'mint leaves': 3,
#                           'mirin': 2,
#                           'molasses': 1,
#                           'mozzarella cheese': 3,
#                           'mushroom soup': 2,
#                           'mushrooms': 3,
#                           'mustard': 6,
#                           'mustard powder': 3,
#                           'noodles': 2,
#                           'oil': 16,
#                           'oil for frying': 1,
#                           'olive oil': 36,
#                           'olives': 4,
#                           'onion': 70,
#                           'onion powder': 6,
#                           'onion salt': 1,
#                           'onion soup': 2,
#                           'onion soup mix': 5,
#                           'onion)': 1,
#                           'onions': 11,
#                           'or bottle beer': 2,
#                           'or bottle root beer': 1,
#                           'or pepper or to taste': 1,
#                           'or porter': 1,
#                           'oregano': 28,
#                           'oyster sauce': 1,
#                           'pan drippings from rib': 1,
#                           'paprika': 16,
#                           'parsley': 22,
#                           'parsnips': 1,
#                           'partridge breast halves': 1,
#                           'pears': 1,
#                           'peas': 5,
#                           'peas and carrots': 1,
#                           'pecans': 1,
#                           'peeled seeded': 1,
#                           'pepper': 69,
#                           'pepper flakes': 7,
#                           'pepper sauce': 8,
#                           'peppercorns': 1,
#                           'phyllo dough': 1,
#                           'pie crusts': 1,
#                           'pinto beans': 1,
#                           'pinto beans and': 1,
#                           'pita breads': 1,
#                           'pizza crust dough': 1,
#                           'plum jam': 1,
#                           'plum tomatoes': 1,
#                           'plum wine': 1,
#                           'pork': 1,
#                           'pork belly': 1,
#                           'pork chops': 1,
#                           'pork loin roast': 1,
#                           'pork ribs': 1,
#                           'pork sausage': 1,
#                           'pork shoulder': 1,
#                           'pork shoulder roast': 2,
#                           'port wine': 1,
#                           'pot roast': 1,
#                           'potatoes': 12,
#                           'provolone cheese': 1,
#                           'pureed chipotle peppers in adobo sauce': 1,
#                           'rabbit meat and into pieces': 1,
#                           'rack baby pork ribs': 1,
#                           'rack of lamb and': 1,
#                           'ranch dressing': 1,
#                           'ribs': 3,
#                           'rice': 3,
#                           'roast': 2,
#                           'rolls': 2,
#                           'rump roast': 1,
#                           'rutabaga': 1,
#                           'saffron': 1,
#                           'sage': 1,
#                           'salad dressing': 2,
#                           'salad dressing mix': 2,
#                           'salsa': 2,
#                           'salt': 64,
#                           'salt and pepper': 24,
#                           'salt and pepper or to taste': 1,
#                           'sauce': 8,
#                           'sausage': 5,
#                           'savory': 1,
#                           'sazon seasoning': 1,
#                           'sea salt': 4,
#                           'seasoning': 4,
#                           'seasoning or to taste': 1,
#                           'seasoning salt': 1,
#                           'seeds': 1,
#                           'sesame oil': 2,
#                           'sesame seeds': 1,
#                           'shallots': 7,
#                           'shanks': 2,
#                           'sherry': 2,
#                           'shoulder roast': 1,
#                           'shrimp without tails': 1,
#                           'size flour tortillas': 1,
#                           'skewers': 1,
#                           'smoke flavoring': 3,
#                           'smokie sausages': 1,
#                           'soy sauce': 14,
#                           'spaghetti sauce': 1,
#                           'spinach': 2,
#                           'sprig': 1,
#                           'sriracha sauce': 1,
#                           'steak sauce': 1,
#                           'steak seasoning or to taste': 1,
#                           'steak seasoning rub': 1,
#                           'sticks': 1,
#                           'sugar': 35,
#                           'sugar)': 1,
#                           'taco sauce': 1,
#                           'taco seasoning': 1,
#                           'taco seasoning mix': 1,
#                           'tarragon': 2,
#                           'tenderloin': 2,
#                           'thyme': 19,
#                           'tomato juice': 1,
#                           'tomato paste': 8,
#                           'tomato sauce': 12,
#                           'tomato soup': 2,
#                           'tomatoes': 18,
#                           'tomatoes with chile peppers': 1,
#                           'tomatoes with chiles': 1,
#                           'tomatoes with chilies': 1,
#                           'tomatoes with juice': 5,
#                           'toothpicks': 2,
#                           'tortellini pasta': 1,
#                           'tortilla chips': 1,
# ...
#                                                               'finely diced',
#                                                               'minced',
#                                                               'quartered',
#                                                               'sliced',
#                                                               'thinly sliced'},
#                                                     'onion powder': {None},
#                                                     'onion powder or flakes': {None},
#                                                     'onions': {None,
#                                                                'chopped',
#                                                                'cut into '
#                                                                '1-inch strips',
#                                                                'halved and '
#                                                                'sliced',
#                                                                'halved '
#                                                                'lengthwise',
#                                                                'minced',
#                                                                'sliced',
#                                                                'thinly sliced '
#                                                                'diagonally',
#                                                                'whites cut '
#                                                                'thinly across '
#                                                                'and greens '
#                                                                'sliced into '
#                                                                'thin lengths - '
#                                                                'divided'},
#                                                     'or to taste': {None},
#                                                     'oregano': {None,
#                                                                 'divided'},
#                                                     'oyster sauce': {None},
#                                                     'paprika': {None},
#                                                     'parsley': {None},
#                                                     'pasta': {None},
#                                                     'pasta shells': {None},
#                                                     'peanut butter': {None},
#                                                     'peanut oil': {None},
#                                                     'peanut sauce': {None},
#                                                     'peanuts': {None},
#                                                     'peas': {None, 'thawed'},
#                                                     'pecans': {None},
#                                                     'pepper': {None},
#                                                     'pepper flakes': {None},
#                                                     'pepper paste': {None},
#                                                     'peppers': {'seeded and '
#                                                                 'minced'},
#                                                     'pickle relish': {None},
#                                                     'pie crust': {None},
#                                                     'piece ginger root': {'peeled '
#                                                                           'and '
#                                                                           'minced',
#                                                                           'thinly '
#                                                                           'sliced'},
#                                                     'polenta': {None},
#                                                     'potatoes': {None,
#                                                                  'cubed',
#                                                                  'peeled and '
#                                                                  'cut into '
#                                                                  '1-inch cubes',
#                                                                  'quartered'},
#                                                     'poultry seasoning': {None},
#                                                     'protein': {None},
#                                                     'raisins': {None},
#                                                     'rice': {None},
#                                                     'rice vermicelli': {None},
#                                                     'rice vinegar': {None},
#                                                     'rice wine vinegar': {None},
#                                                     'rolls': {'split and '
#                                                               'toasted'},
#                                                     'roma tomatoes': {'chopped'},
#                                                     'rotini pasta': {None},
#                                                     'rye bread': {None},
#                                                     'sage': {None},
#                                                     'salsa': {'divided', None},
#                                                     'salt': {None,
#                                                              'or to taste'},
#                                                     'salt and pepper': {None},
#                                                     'sauce': {None},
#                                                     'sauerkraut': {None},
#                                                     'sausage links': {None},
#                                                     'savory': {None},
#                                                     'seashell pasta': {None},
#                                                     'seasoning': {None},
#                                                     'seitan': {None},
#                                                     'semisweet chocolate chips': {None},
#                                                     'sesame oil': {None},
#                                                     'sesame oil or to taste': {None},
#                                                     'sesame seeds': {None,
#                                                                      'or to '
#                                                                      'taste'},
#                                                     'shallots': {'thinly '
#                                                                  'sliced'},
#                                                     'smoke flavoring': {None},
#                                                     'snow peas': {'trimmed'},
#                                                     'soy cheese': {None},
#                                                     'soy crumbles': {None},
#                                                     'soy margarine': {None},
#                                                     'soy milk': {None},
#                                                     'soy sauce': {None,
#                                                                   'divided'},
#                                                     'spaghetti sauce': {None},
#                                                     'spinach': {'stems removed',
#                                                                 'thawed and '
#                                                                 'drained',
#                                                                 'washed and '
#                                                                 'chopped'},
#                                                     'spinach leaves': {None},
#                                                     'spray': {None},
#                                                     'sprig dill weed': {'chopped'},
#                                                     'sriracha chili garlic sauce': {None},
#                                                     'sugar': {None},
#                                                     'sushi or rice': {None},
#                                                     'taco seasoning mix': {None},
#                                                     'taco shells': {'heated'},
#                                                     'tamari': {None},
#                                                     'tempeh': {None,
#                                                                'broken into '
#                                                                'bite-sized '
#                                                                'pieces',
#                                                                'coarsely '
#                                                                'grated',
#                                                                'crumbled'},
#                                                     'thousand island salad dressing': {None},
#                                                     'thyme': {None},
#                                                     'toasted sesame oil': {None},
#                                                     'tofu': {None,
#                                                              'crumbled',
#                                                              'cubed',
#                                                              'cut into 1-inch '
#                                                              'cubes',
#                                                              'cut into '
#                                                              '1/4-inch cubes',
#                                                              'cut into 3/4 '
#                                                              'inch cubes',
#                                                              'cut into '
#                                                              'bite-size pieces',
#                                                              'cut into '
#                                                              'bite-sized cubes',
#                                                              'diced',
#                                                              'drained',
#                                                              'drained and '
#                                                              'cubed',
#                                                              'drained and cut '
#                                                              'into cubes',
#                                                              'drained and cut '
#                                                              'into strips',
#                                                              'drained and '
#                                                              'diced',
#                                                              'drained and '
#                                                              'pressed',
#                                                              'drained and '
#                                                              'sliced into '
#                                                              'large chunks',
#                                                              'drained, '
#                                                              'crumbled',
#                                                              'drained, patted '
#                                                              'dry, and sliced '
#                                                              'into 4 slices',
#                                                              'plain or '
#                                                              'seasoned',
#                                                              'sliced and well '
#                                                              'drained',
#                                                              'sliced into 1/4 '
#                                                              'inch slices',
#                                                              'sliced into 8 '
#                                                              'even pieces',
#                                                              'undrained'},
#                                                     'tomato': {None,
#                                                                'chopped',
#                                                                'seeded and '
#                                                                'chopped'},
#                                                     'tomato juice': {None},
#                                                     'tomato paste': {None},
#                                                     'tomato sauce': {None},
#                                                     'tomatoes': {None,
#                                                                  'chopped',
#                                                                  'drained, 1/4 '
#                                                                  'cup juice '
#                                                                  'reserved',
#                                                                  'undrained'},
#                                                     'tomatoes with juice': {None},
#                                                     'tortillas': {None},
#                                                     'turbinado sugar': {None},
#                                                     'turmeric': {None},
#                                                     'vanilla extract': {None},
#                                                     'vegan cream cheese substitute': {None},
#                                                     'vegan mayonnaise': {None},
#                                                     'vegan sausage)': {'cut '
#                                                                        'into '
#                                                                        '1/4 '
#                                                                        'inch '
#                                                                        'slices '
#                                                                        '(optional'},
#                                                     'vegetables': {None},
#                                                     'vinegar': {None},
#                                                     'virgin olive oil': {None},
#                                                     'water': {None,
#                                                               'or more as '
#                                                               'needed'},
#                                                     'water chestnuts': {'drained'},
#                                                     'wheat': {None},
#                                                     'wheat flour': {None},
#                                                     'wheat hamburger buns': {'split'},
#                                                     'white': {None},
#                                                     'wine': {None},
#                                                     'yeast': {None},
#                                                     'yogurt': {None},
#                                                     'zest': {None},
#                                                     'zucchini': {None,
#                                                                  'cut into '
#                                                                  'large chunks',
#                                                                  'diced'}})}}

# %%
seafood_ingredient = ingredients_categorized['seafood']['ingredients']
meat_ingredient = ingredients_categorized['meat']['ingredients']
vegetarian_protein_ingredient = ingredients_categorized['vegetarian_protein']['ingredients']

# %%
sorted(ingredients_categorized['vegetarian_protein']['descriptor'].items(), key=lambda pair: pair[1], reverse=True)
# Out:
# [('oregano', {None, 'chopped fresh', 'dried'}),
#  ('onion',
#   {None,
#    'chopped',
#    'diced',
#    'dried minced',
#    'finely chopped',
#    'green',
#    'large red',
#    'large yellow',
#    'medium',
#    'minced',
#    'red',
#    'small',
#    'small red'}),
#  ('broth', {'vegetable', 'vegetarian chicken-flavored'}),
#  ('garlic', {None, 'minced'}),
#  ('pepper',
#   {None,
#    'black',
#    'crushed red',
#    'freshly ground black',
#    'ground black',
#    'ground red',
#    'ground red, optional'}),
#  ('tempeh', {None, 'spicy flavored'}),
#  ('tofu',
#   {None,
#    'baked',
#    'crumbled firm silken',
#    'extra firm',
#    'extra-firm',
#    'firm',
#    'firm water-packed',
#    'fried',
#    'silken',
#    'soft',
#    'soft silken',
#    'thinly sliced firm'}),
#  ('zucchini', {None, 'shredded'}),
#  ('bell pepper',
#   {'chopped green',
#    'chopped red',
#    'green',
#    'minced green',
#    'red',
#    'small red',
#    'yellow'}),
#  ('sesame oil', {None, 'divided'}),
#  ('soy sauce', {None, 'dark'}),
#  ('mushrooms',
#   {None,
#    'chopped',
#    'chopped fresh',
#    'fresh',
#    'fresh shiitake',
#    'large',
#    'sliced'}),
#  ('jalapeno pepper', {None, 'fresh'}),
#  ('cumin', {None, 'ground'}),
#  ('taco seasoning mix', {None}),
#  ('sriracha chili garlic sauce', {None}),
#  ('seitan', {'seitan'}),
#  ('oil', {'safflower', 'vegetable'}),
#  ('yeast', {'nutritional', 'nutritional, optional'}),
#  ('tamari', {'tamari'}),
#  ('coriander', {'ground'}),
#  ('celery', {None, 'chopped', 'diced', 'minced'}),
#  ('tomato', {None, 'large'}),
#  ('potatoes', {None, 'russet', 'shredded sweet', 'small'}),
#  ('vegan cream cheese substitute', {'such as Tofutti ®'}),
#  ('salt', {None, 'seasoned'}),
#  ('beef substitute', {'vegetarian ground'}),
#  ('carrots', {None, 'shredded', 'sliced', 'small'}),
#  ('virgin olive oil', {None}),
#  ('vegan mayonnaise', {None}),
#  ('soy cheese', {'shredded Cheddar-style'}),
#  ('peas', {'frozen'}),
#  ('soy milk', {None, 'sweetened plain'}),
#  ('cilantro',
#   {None,
#    'chopped',
#    'chopped fresh',
#    'coarsely chopped fresh',
#    'fresh chopped'}),
#  ('garlic powder', {None}),
#  ('seasoning', {None}),
#  ('olive oil', {None}),
#  ('mirin', {'sweetened rice wine'}),
#  ('ginger', {'ground', 'minced fresh'}),
#  ('barbecue sauce', {None}),
#  ('spinach', {'fresh', 'frozen chopped'}),
#  ('cheese', {'Swiss', 'ricotta', 'shredded Swiss'}),
#  ('9 inch pie crust', {None}),
#  ('Cheddar cheese', {'shredded'}),
#  ('chile peppers', {'chopped green', 'diced green', 'fresh green'}),
#  ('lime juice', {None, 'fresh'}),
#  ('rice vinegar', {None}),
#  ('sesame seeds', {None}),
#  ('sesame oil or to taste', {None}),
#  ('rolls', {None}),
#  ('1% milk', {None}),
#  ('corn oil', {None}),
#  ('tomato sauce', {None}),
#  ('Parmesan cheese', {None}),
#  ('mozzarella cheese', {'shredded'}),
#  ('basil', {'chopped fresh', 'dried'}),
#  ('bread crumbs', {None, 'seasoned'}),
#  ('sugar', {None, 'brown', 'light brown', 'white'}),
#  ('roma tomatoes', {'plum'}),
#  ('onions', {None, 'chopped green', 'green', 'medium', 'medium green'}),
#  ('curry powder', {None, 'vindaloo'}),
#  ('coconut milk', {None, 'light'}),
#  ('bok choy', {'chopped'}),
#  ('vinegar', {'Chinese black', None, 'distilled white', 'white'}),
#  ('ketchup', {None}),
#  ('sauce', {'barbeque', 'enchilada', 'hot'}),
#  ('smoke flavoring', {'liquid'}),
#  ('water', {None, 'cold', 'hot', 'warm'}),
#  ('head broccoli', {'small'}),
#  ('cayenne pepper', {None, 'ground'}),
#  ('cocoa powder', {None, 'unsweetened'}),
#  ('maple syrup', {None}),
#  ('molasses', {None}),
#  ('pepper flakes', {'crushed red', 'red'}),
#  ('chile pepper', {'green'}),
#  ('cornstarch', {None}),
#  ('white', {'white'}),
#  ('flour', {'all-purpose'}),
#  ('ground nutmeg', {'ground nutmeg'}),
#  ('lasagna noodles', {None, 'uncooked'}),
#  ('canola oil', {None}),
#  ('parsley', {'chopped', 'chopped fresh', 'dried'}),
#  ('eggs', {None, 'jumbo'}),
#  ('peanut oil', {None}),
#  ('garbanzo beans', {'chickpeas'}),
#  ('curry paste', {None, 'green', 'red'}),
#  ('spaghetti sauce', {None}),
#  ('corn', {'creamed'}),
#  ('sage', {None, 'dried', 'ground'}),
#  ('chile paste', {None}),
#  ('peanut butter', {None}),
#  ('crumbles', {'frozen burger-style'}),
#  ('kidney beans', {None, 'dark red', 'dry', 'light red'}),
#  ('butter or margarine', {None}),
#  ('beans', {'black', 'dry white', 'fresh green', 'vegetarian refried'}),
#  ('tomatoes', {None, 'chopped fresh', 'diced', 'stewed', 'whole'}),
#  ('milk', {None}),
#  ('salt and pepper', {None}),
#  ('chili powder', {None}),
#  ('tomato juice', {None}),
#  ('bell peppers', {'green', 'large green', 'orange', 'red'}),
#  ('protein', {'textured vegetable', 'texturized vegetable, TVP'}),
#  ('rice',
#   {'brown', 'cooked white', 'uncooked brown', 'uncooked white', 'white'}),
#  ('tortillas', {None}),
#  ('olives', {'sliced black'}),
#  ('pepper paste', {'red'}),
#  ('carrot', {None, 'chopped', 'grated'}),
#  ('leaves', {None}),
#  ('peanut sauce', {None}),
#  ('peanuts', {'chopped'}),
#  ('vegetables', {'frozen stir-fry'}),
#  ('buns', {None}),
#  ('oil for frying', {None}),
#  ('juice', {'fresh orange', 'orange'}),
#  ('chili paste', {None}),
#  ('tomato paste', {None}),
#  ('lime', {None}),
#  ('salsa', {None}),
#  ('garden herb tofu', {'crumbled'}),
#  ('avocado', {None}),
#  ('lettuce', {'shredded'}),
#  ('paprika', {None}),
#  ('taco shells', {'medium'}),
#  ('burger crumbles', {'vegetarian'}),
#  ('bread', {None}),
#  ('spray', {None}),
#  ('Worcestershire sauce', {None}),
#  ('mustard', {'prepared'}),
#  ('beef', {'vegetarian ground, e.g., Gimme Lean TM'}),
#  ('mayonnaise', {None}),
#  ('dill weed', {'dried'}),
#  ('turmeric', {'ground'}),
#  ('pickle relish', {'sweet'}),
#  ('ginger root', {'fresh', 'grated fresh', 'minced fresh'}),
#  ('butter', {None, 'unsalted'}),
#  ('Parmesan or cheese', {None}),
#  ('flour tortillas', {'burrito-size'}),
#  ('soy crumbles', {'frozen burger-style'}),
#  ('bean sprouts', {None, 'fresh'}),
#  ('milk or soy milk', {None}),
#  ('jalapeno peppers', {'fresh'}),
#  ('cornstarch in', {None}),
#  ('head bok choy', {'small'}),
#  ('toasted sesame oil', {None}),
#  ('agave nectar', {None}),
#  ('wheat flour', {'whole'}),
#  ('wine', {'dry white'}),
#  ('bouillon', {'vegetable'}),
#  ('chipotle chile pepper', {'dried, optional'}),
#  ('broccoli', {None, 'frozen'}),
#  ('oyster sauce', {None, 'flavored'}),
#  ('lemon juice', {None, 'fresh'}),
#  ('baby corn', {None}),
#  ('semisweet chocolate chips', {None}),
#  ('chicken broth', {None}),
#  ('cranberries', {'sweetened dried'}),
#  ('pecans', {'chopped'}),
#  ('pasta shells', {'jumbo'}),
#  ('piece ginger root', {'fresh'}),
#  ('fish sauce', {'vegetarian, optional'}),
#  ('dairy cream', {'sour'}),
#  ('cinnamon', {None, 'ground'}),
#  ('egg noodles', {None, 'uncooked'}),
#  ('rice wine vinegar', {None}),
#  ('bamboo shoots', {None}),
#  ('honey', {None}),
#  ('vanilla extract', {None}),
#  ('cooking sherry', {None}),
#  ('Monterey Jack cheese', {None}),
#  ('leaf', {None}),
#  ('shallots', {None}),
#  ('lemon grass', {None}),
#  ('lime leaves', {None}),
#  ('tomatoes with juice', {None}),
#  ('kidney beans with', {None}),
#  ('cottage cheese', {None}),
#  ('cream', {'half-and-half', 'sour'}),
#  ('sprig dill weed', {'fresh'}),
#  ('snow peas', {None}),
#  ('chili sauce', {'Thai', 'sweet'}),
#  ('cabbage', {'finely shredded red'}),
#  ('hamburger buns', {None}),
#  ('thyme', {'chopped fresh', 'dried'}),
#  ('celery seed', {None}),
#  ('seashell pasta', {None}),
#  ('cider vinegar', {None}),
#  ('graham cracker crust', {'prepared'}),
#  ('Dijon mustard', {None}),
#  ('pie crust', {'unbaked'}),
#  ('Parmesan flavor soy cheese', {None}),
#  ('hoisin sauce', {None}),
#  ('cumin seeds', {None}),
#  ('cheese blend', {'shredded reduced-fat mild Cheddar-mozzarella'}),
#  ('curd cottage cheese', {'low-fat small'}),
#  ('sausage links', {'vegetarian, such as Morningstar Farms®'}),
#  ('spinach leaves', {'finely sliced fresh'}),
#  ('marinara sauce', {None}),
#  ('into florets', {'cauliflower cut'}),
#  ('marjoram', {'dried'}),
#  ('raisins', {None}),
#  ('poultry seasoning', {None}),
#  ('dried rosemary', {'dried rosemary'}),
#  ('rye bread', {None}),
#  ('thousand island salad dressing', {None}),
#  ('sauerkraut', {None}),
#  ('rice vermicelli', {'dried'}),
#  ('limes', {None}),
#  ('chili flakes', {'dried red'}),
#  ('egg', {None, 'large'}),
#  ('head', {'small cauliflower'}),
#  ('peppers', {None}),
#  ('garam masala', {None}),
#  ('yogurt', {'plain'}),
#  ('honey mustard', {None}),
#  ('zest', {None}),
#  ('herb stuffing', {'prepared'}),
#  ('fresh rosemary', {'fresh rosemary'}),
#  ('miso paste', {None}),
#  ('or to taste', {'tamari'}),
#  ('baby spinach leaves', {None}),
#  ('sushi or rice', {None}),
#  ('turbinado sugar', {None}),
#  ('coffee powder', {'instant decaffeinated'}),
#  ('wheat', {'vital gluten'}),
#  ('amino acid', {'liquid, such as Bragg®'}),
#  ('kernel corn', {'undrained'}),
#  ("confectioners' sugar", {None}),
#  ('banana', {None}),
#  ('basmati rice', {'uncooked'}),
#  ('kelp powder', {None}),
#  ('wheat hamburger buns', {'whole'}),
#  ('Tartar Sauce', {None}),
#  ('onion powder or flakes', {None}),
#  ('dill pickle relish', {None}),
#  ('soy margarine', {None}),
#  ('jam', {'orange'}),
#  ('bread stuffing mix', {'dry'}),
#  ('savory', {'dried'}),
#  ('lentils', {'dry', 'dry brown'}),
#  ('kale', {None}),
#  ('vegan sausage)', {None}),
#  ('rotini pasta', {None}),
#  ('cornmeal', {None}),
#  ('baking powder', {None}),
#  ('pasta', {'linguine'}),
#  ('habanero peppers', {None}),
#  ('bananas', {None}),
#  ('mango', {'large'}),
#  ('avocados', {None}),
#  ('polenta', {'prepared'}),
#  ('eggplants', {'small'}),
#  ('onion powder', {None}),
#  ('cooking spray', {None}),
#  ('water chestnuts', {None})]

# %%
# load selected meat list
meat_dict = {}
with open('../data/selected_meat_ingredients.txt', 'r') as file:
    for line in file:
        meat_dict[line.strip()] = {}
file.close()

# populate ingredients_categorized' measurements, descriptors, and preparations from scraped data
# we combined both meat and seafood
for i in meat_dict:
    if i in ingredients_categorized['meat']['measurement']:
        meat_dict[i]['measurement'] = ingredients_categorized['meat']['measurement'][i]
    if i in ingredients_categorized['meat']['descriptor']:
        meat_dict[i]['descriptor'] = ingredients_categorized['meat']['descriptor'][i]
    if i in ingredients_categorized['meat']['preparation']:
        meat_dict[i]['preparation'] = ingredients_categorized['meat']['preparation'][i]

for i in meat_dict:
    if i in ingredients_categorized['seafood']['measurement']:
        meat_dict[i]['measurement'] = ingredients_categorized['seafood']['measurement'][i]
    if i in ingredients_categorized['seafood']['descriptor']:
        meat_dict[i]['descriptor'] = ingredients_categorized['seafood']['descriptor'][i]
    if i in ingredients_categorized['seafood']['preparation']:
        meat_dict[i]['preparation'] = ingredients_categorized['seafood']['preparation'][i]
        
# for ingredients_categorized not in scraped data, manually add general data
for i in meat_dict:
    if i not in ingredients_categorized['meat']['measurement']:
        meat_dict[i]['measurement'] = ['pound']
    if i not in ingredients_categorized['meat']['descriptor']:
        meat_dict[i]['descriptor'] = ['fresh', 'raw', None]
    if i not in ingredients_categorized['meat']['preparation']:
        meat_dict[i]['preparation'] = ['cut into cubes']
        
pprint.pprint(meat_dict)
# Out:
# {'alligator': {'descriptor': ['fresh', 'raw', None],
#                'measurement': ['pound'],
#                'preparation': ['cut into cubes']},
#  'bacon': {'descriptor': {None,
#                           'cooked',
#                           'thick cut',
#                           'thick sliced',
#                           'thickly sliced'},
#            'measurement': {'slices', 'pounds', 'pound'},
#            'preparation': {None,
#                            'chopped',
#                            'cut in half',
#                            'cut into 1/2 inch pieces',
#                            'diced',
#                            'minced'}},
#  'bass': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'beef': {'descriptor': {'lean ground', 'ground', 'extra lean ground'},
#           'measurement': {'pounds', 'pound'},
#           'preparation': {None}},
#  'belly': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'bison': {'descriptor': {'ground'},
#            'measurement': {'pound'},
#            'preparation': {None}},
#  'boart': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'breast': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'buffalo': {'descriptor': {'ground'},
#              'measurement': {'pound'},
#              'preparation': {None}},
#  'caribou': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'carp': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'catfish': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'chicken': {'descriptor': {'shredded cooked', 'cooked', 'whole'},
#              'measurement': {None, 'pound', 'cups'},
#              'preparation': {None,
#                              'cut into bite-size pieces',
#                              'cut into pieces'}},
#  'chicken breasts': {'descriptor': {'boneless skinless',
#                                     'whole skinless boneless'},
#                      'measurement': {'pounds', None},
#                      'preparation': {None, 'cut into 1/2-inch chunks'}},
#  'chop': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'crayfish': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'deer': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'duck': {'descriptor': {'frozen', 'whole'},
#           'measurement': {None},
#           'preparation': {'dressed', None}},
#  'elk': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'fish': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'frog': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'goat': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'goose': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'guanciale': {'descriptor': {'cured pork cheek'},
#                'measurement': {'ounces'},
#                'preparation': {'sliced'}},
#  'guineafowl': {'descriptor': ['fresh', 'raw', None],
#                 'measurement': ['pound'],
#                 'preparation': ['cut into cubes']},
#  'ham': {'descriptor': {'diced cooked', None, 'cooked diced'},
#          'measurement': {'slices', 'cup', 'ounces'},
#          'preparation': {None}},
#  'lamb': {'descriptor': {'lean ground', 'ground', 'cubed cooked'},
#           'measurement': {'pounds', 'pound', 'cups'},
#           'preparation': {None}},
#  'leg': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'liver': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'lobster': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'meat': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'meatball': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'meatloaf': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'moose': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'mussel': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'oyster': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'pheasant': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'pork': {'descriptor': {'ground'},
#           'measurement': {'pound'},
#           'preparation': {None}},
#  'prawn': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'quail': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'rabbit': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'reindeer': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'rib': {'descriptor': ['fresh', 'raw', None],
#          'measurement': ['pound'],
#          'preparation': ['cut into cubes']},
#  'ribs': {'descriptor': {None, 'Korean-style short, beef chuck flanken'},
#           'measurement': {'celery', 'pounds'},
#           'preparation': {'chopped', 'cut 1/3 to 1/2 inch thick across bones'}},
#  'rump': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'salmon': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'sausage': {'descriptor': {'Italian', 'sweet Italian'},
#              'measurement': {'pound'},
#              'preparation': {None,
#                              'casings removed',
#                              'casings removed and crumbled'}},
#  'scallop': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'shanks': {'descriptor': {None},
#             'measurement': {'lamb'},
#             'preparation': {None}},
#  'sheep': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'shoulder': {'descriptor': ['fresh', 'raw', None],
#               'measurement': ['pound'],
#               'preparation': ['cut into cubes']},
#  'shrimp': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'skewer': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'snail': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'steak': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'tenderloin': {'descriptor': {None},
#                 'measurement': {'pork'},
#                 'preparation': {None}},
#  'thigh': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'tilapia': {'descriptor': ['fresh', 'raw', None],
#              'measurement': ['pound'],
#              'preparation': ['cut into cubes']},
#  'tripe': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'trout': {'descriptor': ['fresh', 'raw', None],
#            'measurement': ['pound'],
#            'preparation': ['cut into cubes']},
#  'turkey': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'turtle': {'descriptor': ['fresh', 'raw', None],
#             'measurement': ['pound'],
#             'preparation': ['cut into cubes']},
#  'veal': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']},
#  'venison': {'descriptor': {'ground', None},
#              'measurement': {'pounds', 'pound'},
#              'preparation': {None,
#                              'cut into 1/4 thick strips',
#                              'cut into 2 inch strips',
#                              'cut into cubes'}},
#  'wing': {'descriptor': ['fresh', 'raw', None],
#           'measurement': ['pound'],
#           'preparation': ['cut into cubes']}}

# %%
# load selected vegetarian protein list
vegetarian_dict = {}
with open('../data/selected_vegetarian_ingredients.txt', 'r') as file:
    for line in file:
        vegetarian_dict[line.strip()] = {}
file.close()

for i in vegetarian_dict:
    if i in ingredients_categorized['vegetarian_protein']['measurement']:
        vegetarian_dict[i]['measurement'] = ingredients_categorized['vegetarian_protein']['measurement'][i]
    else:
        vegetarian_dict[i]['measurement'] = ['cup', 'can']
    if i in ingredients_categorized['vegetarian_protein']['descriptor']:
        vegetarian_dict[i]['descriptor'] = ingredients_categorized['vegetarian_protein']['descriptor'][i]
    else:
        vegetarian_dict[i]['descriptor'] = [None]
    if i in ingredients_categorized['vegetarian_protein']['preparation']:
        vegetarian_dict[i]['preparation'] = ingredients_categorized['vegetarian_protein']['preparation'][i]
    else:
        vegetarian_dict[i]['preparation'] = ['drained']

pprint.pprint(vegetarian_dict)
# Out:
# {'chickpeas': {'descriptor': [None],
#                'measurement': ['cup', 'can'],
#                'preparation': ['drained']},
#  'garbanzo beans': {'descriptor': {'chickpeas'},
#                     'measurement': {'can'},
#                     'preparation': {'drained and rinsed'}},
#  'garden herb tofu': {'descriptor': {'crumbled'},
#                       'measurement': {'package'},
#                       'preparation': {None}},
#  'kidney beans': {'descriptor': {'dry', None, 'light red', 'dark red'},
#                   'measurement': {'can', 'cup', 'cans'},
#                   'preparation': {None, 'undrained', 'soaked overnight'}},
#  'seitan': {'descriptor': {'seitan'},
#             'measurement': {'package', 'packages'},
#             'preparation': {None}},
#  'snow peas': {'descriptor': {None},
#                'measurement': {'cup', 'cups'},
#                'preparation': {'trimmed'}},
#  'tempeh': {'descriptor': {'spicy flavored', None},
#             'measurement': {'package', 'packages', 'slice'},
#             'preparation': {None,
#                             'broken into bite-sized pieces',
#                             'coarsely grated',
#                             'crumbled'}},
#  'tofu': {'descriptor': {None,
#                          'baked',
#                          'crumbled firm silken',
#                          'extra firm',
#                          'extra-firm',
#                          'firm',
#                          'firm water-packed',
#                          'fried',
#                          'silken',
#                          'soft',
#                          'soft silken',
#                          'thinly sliced firm'},
#           'measurement': {'container',
#                           'cup',
#                           'cups',
#                           'ounces',
#                           'package',
#                           'packages',
#                           'pound',
#                           'pounds'},
#           'preparation': {None,
#                           'crumbled',
#                           'cubed',
#                           'cut into 1-inch cubes',
#                           'cut into 1/4-inch cubes',
#                           'cut into 3/4 inch cubes',
#                           'cut into bite-size pieces',
#                           'cut into bite-sized cubes',
#                           'diced',
#                           'drained',
#                           'drained and cubed',
#                           'drained and cut into cubes',
#                           'drained and cut into strips',
#                           'drained and diced',
#                           'drained and pressed',
#                           'drained and sliced into large chunks',
#                           'drained, crumbled',
#                           'drained, patted dry, and sliced into 4 slices',
#                           'plain or seasoned',
#                           'sliced and well drained',
#                           'sliced into 1/4 inch slices',
#                           'sliced into 8 even pieces',
#                           'undrained'}},
#  'tofu skewer': {'descriptor': [None],
#                  'measurement': ['cup', 'can'],
#                  'preparation': ['drained']},
#  'vegetarian bacon': {'descriptor': [None],
#                       'measurement': ['cup', 'can'],
#                       'preparation': ['drained']},
#  'vegetarian ham': {'descriptor': [None],
#                     'measurement': ['cup', 'can'],
#                     'preparation': ['drained']},
#  'vegetarian meatball': {'descriptor': [None],
#                          'measurement': ['cup', 'can'],
#                          'preparation': ['drained']},
#  'vegetarian sausage': {'descriptor': [None],
#                         'measurement': ['cup', 'can'],
#                         'preparation': ['drained']}}

# %%
def randomly_select(ls):
    if len(ls) == 0 or (len(ls) == 1 and ls[0] is None):
        return ''
    choice = random.choice(ls)
    if choice is None:
        return randomly_select(ls)
    else:
        return choice

# test
print(randomly_select(list(vegetarian_dict.keys())))
# Out:
# vegetarian bacon

# %%
# custom ingredients substitutions
custom_to_vegetarian_dict = {'frankfurter':'vegetarian sausage',
                            'meatball':'vegetarian meatball',
                            'meatloaf':'tofu',
                            'sausage':'vegetarian sausage',
                            'bacon':'vegetarian bacon',
                            'ham':'vegetarian ham',
                            'skewer':'tofu skewer'}

custom_from_vegetarian_dict = {v: k for k, v in custom_to_vegetarian_dict.items()}

def get_vegetarian_substitution(ingredient):
    if 'stock' in ingredient or 'consomme' in ingredient or 'bouillon' in ingredient:
        return 'vegetable stock'
    if 'broth' in ingredient:
        return 'vegetable broth'
    if ingredient in custom_to_vegetarian_dict:
        return custom_to_vegetarian_dict[ingredient]
    # randomly substitue a vegetarian protein if no custom substitution is found
    return randomly_select(list(vegetarian_dict.keys()))
        
def substitute_with_meat(ingredient):
    if is_broth(ingredient):
        return 'chicken broth'
    if ingredient in custom_from_vegetarian_dict:
        return custom_from_vegetarian_dict[ingredient]
    return randomly_select(list(meat_dict.keys()))

# %%
def is_broth(ingredient):
     if 'stock' in ingredient or 'consomme' in ingredient or 'bouillon' in ingredient or  'broth' in ingredient:
        return True
     return False

def is_meat(ingredient):
    if ingredient in meat_dict:
        return True
    if is_broth(ingredient):
        return True
    return False

def is_vegetable(ingredient):
    if ingredient in vegetarian_protein_ingredient:
        return True
    if is_broth(ingredient):
        return True
    return False

# %% [markdown]
# # Transform to Vegetarian

# %%
url = 'https://www.allrecipes.com/recipe/219763/chicken-marsala-over-white-rice/'
url = 'https://www.allrecipes.com/recipe/45736/chicken-tikka-masala'
url = 'https://www.allrecipes.com/recipe/13183/restaurant-style-zuppa-toscana/'
recipe = Recipe(url)

# %%
def generate_new_ingredients_and_sub_dict():
    sub_dict = {}
    new_ingredients = []
    
    for line in recipe.ingredients:
        quantity, measurement, descriptor, ingredient, preparation = recipe.extract_all(line)


        # if ingredient is meat
        if is_meat(ingredient):
            sub = get_vegetarian_substitution(ingredient)
            sub_dict[ingredient] = {}

            # if ingredient is broth
            if is_broth(ingredient):
                sub_measurement = measurement
                sub_preparation = None
                sub_descriptor = None
            else:
                sub_measurement = randomly_select(list(vegetarian_dict[sub]['measurement']))
                sub_descriptor = randomly_select(list(vegetarian_dict[sub]['descriptor']))
                sub_preparation = randomly_select(list(vegetarian_dict[sub]['preparation']))

            # record substitution information
            sub_dict[ingredient]['substitution'] = sub
            sub_dict[ingredient]['measurement'] = sub_measurement
            sub_dict[ingredient]['descriptor'] = sub_descriptor
            sub_dict[ingredient]['preparation'] = sub_preparation

            # pick not None element only
            replacement = []
            for i in ['1', sub_measurement, sub_descriptor, sub]:
                if i is not None and len(i) != 0:
                    replacement.append(i)        

            print('\nREPLACE:')
            print('\t' + line)
            print('TO:')
            print('\t' + ' '.join(replacement) + '\n')
            new_ingredients.append(' '.join(replacement))
        else:
            print(line)
            new_ingredients.append(line)
        
    return new_ingredients, sub_dict

new_ingredients, sub_dict = generate_new_ingredients_and_sub_dict()
# Out:
# 1/3 cup heavy whipping cream
#
# REPLACE:
# 	6 slices bacon
# TO:
# 	1 cup vegetarian bacon
#
# 3/4 cup chopped onion
#
# REPLACE:
# 	1 (16 ounce) package smoked sausage
# TO:
# 	1 cup vegetarian sausage
#
# 1 1/2 teaspoons minced garlic
# 2 cups kale - washed, dried, and shredded
# 2 tablespoons chicken soup base
# 2 potatoes, cut into 1/4-inch slices
# 1 quart water

# %%
# expand sub_dict() for better granularity
def generate_sub_dict_granular(sub_dict):
    sub_dict_granular = {}
    for ingredient in sub_dict.keys():
        if len(ingredient.split()) > 1: 
            for word in ingredient.split():
                sub_dict_granular[word] = {}
                sub_dict_granular[word]['substitution'] = sub_dict[ingredient]['substitution']
                sub_dict_granular[word]['measurement'] = sub_dict[ingredient]['measurement']
                sub_dict_granular[word]['descriptor'] = sub_dict[ingredient]['descriptor']
                sub_dict_granular[word]['preparation'] = sub_dict[ingredient]['preparation']
    return sub_dict_granular

sub_dict_granular = generate_sub_dict_granular(sub_dict)

# %%
pprint.pprint(sub_dict)
pprint.pprint(sub_dict_granular)
# Out:
# {'chicken breasts': {'descriptor': '',
#                      'measurement': 'cup',
#                      'preparation': 'drained',
#                      'substitution': 'chickpeas'}}
# {'breasts': {'descriptor': '',
#              'measurement': 'cup',
#              'preparation': 'drained',
#              'substitution': 'chickpeas'},
#  'chicken': {'descriptor': '',
#              'measurement': 'cup',
#              'preparation': 'drained',
#              'substitution': 'chickpeas'}}

# %%
def generate_transformed_directions():
    substitution_words = set()
    new_directions = []
    
    for direction in recipe.directions:
        new_direction = direction

        bulk_substitution = False
        for ingredient in sub_dict.keys():
            if ingredient in direction:
                new_direction = direction.replace(ingredient, sub_dict[ingredient]['substitution'])
                bulk_substitution = True
                for i in sub_dict[ingredient]['substitution'].split():
                    substitution_words |= {i}
                print("Replaced '{0}' to '{1}':".format(ingredient, sub_dict[ingredient]['substitution']))

        if not bulk_substitution:
            for word in sub_dict_granular.keys():
                if word in new_direction and word not in substitution_words:
                    new_direction = new_direction.replace(word, sub_dict_granular[word]['substitution'])
                    for i in sub_dict_granular[word]['substitution'].split():
                        substitution_words |= {i}
                    print("Replaced '{0}' to '{1}':".format(word, sub_dict_granular[word]['substitution']))
        
        new_directions.append(new_direction)
        
        if direction != new_direction:
            print('REPLACE:')
            print('\t' + direction)
            print('TO:')
            print('\t' + new_direction)
        else:
            print(direction)
        print('-----------------------------------------------------------\n')
        
    return new_directions

generate_transformed_directions()
# Out:
# Replaced 'chicken' to 'chickpeas':
# REPLACE:
# 	In a large bowl, combine yogurt, lemon juice, 2 teaspoons cumin, cinnamon, cayenne, black pepper, ginger, and salt. Stir in chicken, cover, and refrigerate for 1 hour.
# TO:
# 	In a large bowl, combine yogurt, lemon juice, 2 teaspoons cumin, cinnamon, cayenne, black pepper, ginger, and salt. Stir in chickpeas, cover, and refrigerate for 1 hour.
# -----------------------------------------------------------
#
# Preheat a grill for high heat.
# -----------------------------------------------------------
#
# Replaced 'chicken' to 'chickpeas':
# REPLACE:
# 	Lightly oil the grill grate. Thread chicken onto skewers, and discard marinade. Grill until juices run clear, about 5 minutes on each side.
# TO:
# 	Lightly oil the grill grate. Thread chickpeas onto skewers, and discard marinade. Grill until juices run clear, about 5 minutes on each side.
# -----------------------------------------------------------
#
# Replaced 'chicken' to 'chickpeas':
# REPLACE:
# 	Melt butter in a large heavy skillet over medium heat. Saute garlic and jalapeno for 1 minute. Season with 2 teaspoons cumin, paprika, and 3 teaspoons salt. Stir in tomato sauce and cream. Simmer on low heat until sauce thickens, about 20 minutes. Add grilled chicken, and simmer for 10 minutes. Transfer to a serving platter, and garnish with fresh cilantro.
# TO:
# 	Melt butter in a large heavy skillet over medium heat. Saute garlic and jalapeno for 1 minute. Season with 2 teaspoons cumin, paprika, and 3 teaspoons salt. Stir in tomato sauce and cream. Simmer on low heat until sauce thickens, about 20 minutes. Add grilled chickpeas, and simmer for 10 minutes. Transfer to a serving platter, and garnish with fresh cilantro.
# -----------------------------------------------------------
# ['In a large bowl, combine yogurt, lemon juice, 2 teaspoons cumin, cinnamon, cayenne, black pepper, ginger, and salt. Stir in chickpeas, cover, and refrigerate for 1 hour.',
#  'Preheat a grill for high heat.',
#  'Lightly oil the grill grate. Thread chickpeas onto skewers, and discard marinade. Grill until juices run clear, about 5 minutes on each side.',
#  'Melt butter in a large heavy skillet over medium heat. Saute garlic and jalapeno for 1 minute. Season with 2 teaspoons cumin, paprika, and 3 teaspoons salt. Stir in tomato sauce and cream. Simmer on low heat until sauce thickens, about 20 minutes. Add grilled chickpeas, and simmer for 10 minutes. Transfer to a serving platter, and garnish with fresh cilantro.']

# %% [markdown]
# # Transform from Vegetarian to Non-Vegetarian

# %%
# url = 'https://www.allrecipes.com/recipe/246141/pad-thai-with-tofu/'
url = 'https://www.allrecipes.com/recipe/59661/spinach-enchiladas/'
recipe = utils.Recipe(url)

# %%
def generate_new_ingredients_and_sub_dict():
    sub_dict = {}
    new_ingredients = []
    replacement_num = 0

    for line in recipe.ingredients:
        quantity, measurement, descriptor, ingredient, preparation = recipe.extract_all(line)

        # if ingredient is vegetable
        if is_vegetable(ingredient):
            if replacement_num < 2:
                sub = substitute_with_meat(ingredient)
                sub_dict[ingredient] = {}

                sub_quantity = '1/2'
                sub_measurement = randomly_select(list(meat_dict[sub]['measurement']))
                sub_descriptor = randomly_select(list(meat_dict[sub]['descriptor']))
                sub_preparation = randomly_select(list(meat_dict[sub]['preparation']))

                # record substitution information
                sub_dict[ingredient]['substitution'] = sub
                sub_dict[ingredient]['measurement'] = sub_measurement
                sub_dict[ingredient]['descriptor'] = sub_descriptor
                sub_dict[ingredient]['preparation'] = sub_preparation

                # pick not None element only
                replacement = []
                for i in [sub_quantity, sub_measurement, sub_descriptor, sub]:
                    if i is not None:
                        replacement.append(i)  
                new_ingredients.append(' '.join(replacement))

                # update replacement number        
                replacement_num += 1
                print('\nREPLACE:')
                print('\t' + line)
                print('TO:')
                print('\t' + ' '.join(replacement) + '\n')
        else:
            new_ingredients.append(line)
        print(line)
    return new_ingredients, sub_dict

generate_new_ingredients_and_sub_dict();
# Out:
# REPLACE:
# 	1/2 cup sour cream
# TO:
# 	1/2 pound whole chicken
#
# 1/2 cup sour cream
#
# REPLACE:
# 	1 (10 ounce) package frozen chopped spinach , thawed, drained and squeezed dry
# TO:
# 	1/2 pound raw guineafowl
#
# 1 (10 ounce) package frozen chopped spinach , thawed, drained and squeezed dry
# 2 cups shredded Monterey Jack cheese
# 1 (19 ounce) can enchilada sauce
# 1 tablespoon butter
# 10 (6 inch) corn tortillas
# 2 cloves garlic, minced
# 1 cup ricotta cheese
# 1/2 cup sliced green onions

# %%
# expand sub_dict() for better granularity
sub_dict_granular = {}
for ingredient in sub_dict.keys():
    if len(ingredient.split()) > 1: 
        for word in ingredient.split():
            sub_dict_granular[word] = {}
            sub_dict_granular[word]['substitution'] = sub_dict[ingredient]['substitution']
            sub_dict_granular[word]['measurement'] = sub_dict[ingredient]['measurement']
            sub_dict_granular[word]['descriptor'] = sub_dict[ingredient]['descriptor']
            sub_dict_granular[word]['preparation'] = sub_dict[ingredient]['preparation']

# %%
pprint.pprint(sub_dict)
pprint.pprint(sub_dict_granular)
# Out:
# {'cream': {'descriptor': 'fresh',
#            'measurement': 'pound',
#            'preparation': 'cut into cubes',
#            'substitution': 'guineafowl'},
#  'spinach': {'descriptor': 'shredded cooked',
#              'measurement': 'cups',
#              'preparation': 'cut into pieces',
#              'substitution': 'chicken'}}
# {}

# %%
replaced = set()
for direction in recipe.directions:
    new_direction = direction
    
    bulk_substitution = False
    for ingredient in sub_dict.keys():
        if ingredient in direction:
            new_direction = direction.replace(ingredient, sub_dict[ingredient]['substitution'])
            bulk_substitution = True
            for i in sub_dict[ingredient]['substitution'].split():
                replaced |= {i}
            print("Replaced '{0}' to '{1}':".format(ingredient, sub_dict[ingredient]['substitution']))

    if not bulk_substitution:
        for word in sub_dict_granular.keys():
            if word in new_direction and word not in replaced:
                new_direction = new_direction.replace(word, sub_dict_granular[word]['substitution'])
                for i in sub_dict_granular[word]['substitution'].split():
                    replaced |= {i}
                print("Replaced '{0}' to '{1}':".format(word, sub_dict_granular[word]['substitution']))
    
    if direction != new_direction:
        print('REPLACE:')
        print('\t' + direction)
        print('TO:')
        print('\t' + new_direction)
    else:
        print(direction)
    print('-----------------------------------------------------------\n')
# Out:
# Preheat the oven to 375 degrees F (190 degrees C).
# -----------------------------------------------------------
#
# Replaced 'cream' to 'guineafowl':
# Replaced 'spinach' to 'chicken':
# REPLACE:
# 	Melt butter in a saucepan over medium heat. Add garlic and onion; cook for a few minutes until fragrant, but not brown. Stir in spinach, and cook for about 5 more minutes. Remove from the heat, and mix in ricotta cheese, sour cream, and 1 cup of Monterey Jack cheese.
# TO:
# 	Melt butter in a saucepan over medium heat. Add garlic and onion; cook for a few minutes until fragrant, but not brown. Stir in chicken, and cook for about 5 more minutes. Remove from the heat, and mix in ricotta cheese, sour cream, and 1 cup of Monterey Jack cheese.
# -----------------------------------------------------------
#
# Replaced 'spinach' to 'chicken':
# REPLACE:
# 	In a skillet over medium heat, warm tortillas one at a time until flexible, about 15 seconds. Spoon about 1/4 cup of the spinach mixture onto the center of each tortilla. Roll up, and place seam side down in a 9x13 inch baking dish. Pour enchilada sauce over the top, and sprinkle with the remaining cup of Monterey Jack.
# TO:
# 	In a skillet over medium heat, warm tortillas one at a time until flexible, about 15 seconds. Spoon about 1/4 cup of the chicken mixture onto the center of each tortilla. Roll up, and place seam side down in a 9x13 inch baking dish. Pour enchilada sauce over the top, and sprinkle with the remaining cup of Monterey Jack.
# -----------------------------------------------------------
#
# Bake for 15 to 20 minutes in the preheated oven, until sauce is bubbling and cheese is lightly browned at the edges.
# -----------------------------------------------------------
